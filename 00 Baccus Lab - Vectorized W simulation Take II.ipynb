# %% [markdown]
# # Finding the optimal linear filter $w$ that best predicts $y$ in the mean square error sense.
#
# Let $X$ be Toeplitz and $y$ be the shifted copy of $x$.  We seek to find $w$ s.t. $Xw = y$.  Directly this could be solved by $w = (X^T X)^{-1} X^T y$, but in practice $X^T X$ is often ill-conditioned.
#
# $X$ is the $m \times n$ Toeplitz matrix with first row $[x_t, x_{t-1}, \dots, x_{t-n+1}]$ and first column $[x_t, x_{t+1}, \dots, x_{t+m-1}]$.

# %%
import numpy as np
import scipy.linalg
from scipy.linalg import toeplitz
from scipy.linalg import inv
from numpy import fft
import brewer2mpl

from numpy import sin, linspace, pi
from pylab import plot, show, title, xlabel, ylabel, subplot
from scipy import fft, arange

from scipy import signal as sig

# %%
def pinkNoise(duration):
    x_t    = np.random.randn(2*duration)
    x_f    = np.fft.rfft(x_t)[:len(x_t)/2]
    f      = linspace(1,duration,len(x_f))
    fi     = 1./f
    pink_f = x_f*fi

    return real(np.fft.ifft(pink_f))

# %%
def getW(x,y,mode='auto'):
    ''' Solve XW = Y where X is toeplitz, y is a vector.
    
    1) 'auto' mode uses numpy's builtin lstsq solver to avoid
    taking matrix inversions or multiplying by illconditioned matrices.
    2) 'direct' mode uses direct matrix inversion by xtx and returns a 
    warning when xtx is ill-conditioned.
    '''
    
    if mode=='direct':
        xtx = np.dot(np.transpose(x),x)
        con = np.linalg.cond(xtx)
        if con > 10e3:
            print('Condition number of XTX is very high, %f, and inverse wont be accurate.') % (con)
        W = np.dot(np.linalg.inv(xtx), np.dot(np.transpose(x),y))
    elif mode=='auto':
        W, res, rank, s = np.linalg.lstsq(x, y, rcond=-1)
    else:
        print('mode can be either auto or direct')
    
    return W

# %%
def autocorr(x,y):
    result = np.correlate(x, y, mode='full')
    return result[result.size/2:]

# %%
def is_pos_def(x):
    return np.all(np.linalg.eigvals(x) > 0)

# %%
def plotSpectrum(y,Fs=1000.0):
 '''
 Plots a Single-Sided Amplitude Spectrum of y(t).
 
 Example:
 Fs = 1000.0;  # sampling rate
 Ts = 1.0/Fs; # sampling interval
 t = arange(0,len(W)*Ts,len(W)) # time vector

 subplot(2,1,1)
 plot(W, 'k')
 xlim(-5,n+5)
 title('W', fontsize=14)
 ax = gca()
 ax.set_xlim(ax.get_xlim()[::-1])
 xlabel('Time before present', fontsize=14)

 subplot(2,1,2)
 plotSpectrum(W,Fs)
 '''
 n = len(y) # length of the signal
 k = arange(n)
 T = n/Fs
 frq = k/T # two sides frequency range
 frq = frq[range(n/2)] # one side frequency range

 Y = fft(y)/n # fft computing and normalization
 Y = Y[range(n/2)]
 
 plot(frq,abs(Y),'r') # plotting the spectrum
 xlabel('Freq (Hz)')
 ylabel('|Y(freq)|')

# %%
def toe(x,height,width):
    '''x is a vector, height is dimension m = # of predictions,
    and width is dimension n = length of filter.
    '''
    m = height
    n = width
    first_row = x[:n]
    first_row = first_row[::-1] #reverse the first row, since it's x_t, x_t-1, ..., x_t-n+1
    first_col = x[n-1:]  #this should go from n to m but it's weird since python doesn't count the first element

    return toeplitz(first_col,first_row)

# %% [markdown]
# ## Pink Noise

# %%
n = 200     #length of filter = number of times you need in the past
m = 10000   #number of predictions = number of times you need in the future

x_all  = pinkNoise(m+n+1)
x_all  = x_all - np.mean(x_all)
x_all  = x_all/np.sqrt(var(x_all))
x      = x_all[:(m+n)]
y      = x_all[n:] #+ randn(len(x_all[n:-1]))


X_past = toe(x,m,n)
w = getW(X_past,y,mode='auto')

fig = gcf()
fig.set_size_inches(15,10)
subplot(2,2,1)
plot(w,'k')  # w[::-1]
xlim(-5,n+5)
title('Pink Noise W', fontsize=14)
ax = gca()
ax.set_xlim(ax.get_xlim()[::-1])
xlabel('Time before present', fontsize=14)

subplot(2,2,2)
plot(np.dot(X_past,w),'r--')
plot(y,'k',alpha=0.4)
title('Prediction (red) vs Truth (black)')

subplot(2,2,3)
plotSpectrum(w)
title('Frequency spectrum of W')

subplot(2,2,4)
plot(autocorr(y,np.dot(X_past,w)),'k')
title('Autocorrelation between Truth and Prediction')

# %%
sum(np.abs(y - np.dot(X_past,w))**2)
# Out:
# 31.48523105122192

# %%
w
# Out:
# array([  1.05948525e+00,  -5.80339846e-02,   1.11270316e-02,
#          1.80333122e-03,  -1.10616454e-02,  -1.70220188e-02,
#          1.05450599e-02,  -5.68377295e-03,  -1.35142930e-02,
#          2.22239467e-02,   6.55073519e-03,  -1.13478338e-02,
#          9.55082603e-03,  -3.04443954e-03,  -1.15969567e-02,
#         -1.44403944e-02,   3.07249102e-02,  -8.28711643e-03,
#         -1.24858351e-02,   6.66401252e-03,   1.40826157e-02,
#          2.38442061e-03,  -1.31695598e-02,   1.10023120e-02,
#         -1.13953034e-03,   2.84805858e-03,   1.01118431e-02,
#         -3.12232672e-02,  -2.50346371e-03,   1.59439414e-02,
#         -1.09030366e-02,   4.85619833e-03,  -2.07868470e-03,
#          1.63760984e-02,  -3.03838125e-02,   3.68902724e-02,
#         -2.40189589e-02,   3.70432824e-03,   6.19712554e-03,
#         -2.82846100e-02,   2.55619191e-02,  -5.85555089e-03,
#          1.22213203e-02,   1.45960616e-03,  -8.33594953e-03,
#         -6.70964601e-03,   1.16940267e-02,  -2.81416220e-02,
#          2.54972351e-02,   9.38420112e-03,  -4.42674823e-03,
#         -2.34938483e-03,  -2.43982906e-03,   4.63486408e-03,
#         -5.35742377e-03,  -2.05749816e-03,  -1.62226277e-03,
#          1.75372126e-05,  -1.48718995e-02,   1.02666102e-03,
#          1.91427084e-02,  -1.60553370e-03,  -1.90985878e-02,
#          2.98797001e-02,  -7.15501213e-03,   3.92948066e-03,
#         -9.48342084e-03,  -1.32230030e-04,   7.16035853e-03,
#         -4.02783343e-03,  -2.08663594e-02,   2.13340277e-02,
#          1.93159915e-02,  -1.15679023e-02,  -2.71084234e-04,
#         -2.15600604e-03,  -1.37848687e-02,   8.98407308e-04,
#          5.32199689e-03,   8.04677710e-03,  -1.22810127e-02,
#          1.90756817e-02,  -1.27528388e-02,   1.89388643e-02,
#         -2.63020408e-02,   5.74369668e-04,   1.26427108e-02,
#         -6.67515182e-03,  -1.27765187e-02,   1.62223591e-04,
#          1.09243202e-02,  -9.28133569e-03,   1.06931884e-02,
#         -1.72730641e-02,   5.48226916e-03,   1.98687344e-02,
#         -1.06892406e-02,   2.34844691e-03,  -1.70006800e-03,
#         -1.29294325e-02,   2.49695908e-04,   1.97650939e-02,
#         -9.10266068e-03,   1.59763936e-02,   7.60073147e-03,
#         -3.15265482e-02,   1.19378769e-02,  -1.82862252e-02,
#          2.87924435e-02,  -7.12230349e-03,   7.17345885e-03,
#          1.55494096e-03,  -1.57658077e-02,  -1.95314075e-03,
#          1.84500930e-02,  -2.21473375e-02,   1.72182367e-02,
#          1.29340566e-03,  -1.33435495e-02,  -3.77233966e-03,
#         -3.12010511e-03,   1.08964537e-02,  -9.97202908e-03,
#          1.80574303e-02,  -1.04214236e-02,   2.48697280e-03,
#         -1.81738414e-02,   2.59682466e-02,  -1.49759396e-02,
#          7.91166003e-03,  -6.17049956e-03,   1.76372034e-03,
#          2.04603731e-02,  -8.39112264e-03,  -5.40909349e-03,
#          6.55458573e-03,  -2.43772587e-02,   4.68568407e-03,
#          6.57726639e-03,  -3.10178726e-03,   1.49938851e-02,
#         -5.05331097e-03,  -1.50287007e-02,   2.37038529e-02,
#         -1.56011067e-03,  -1.53559608e-02,   1.58005838e-02,
#         -2.67725403e-02,   8.52212360e-03,   2.30748630e-02,
#         -1.36248711e-02,   2.20588044e-02,  -2.05626338e-02,
#         -1.34766039e-02,   2.60295204e-02,  -3.68740091e-02,
#          6.80544136e-03,   8.97106878e-03,   1.62831851e-03,
#          4.16668780e-03,  -1.70494372e-03,  -2.19356307e-03,
#         -2.41095131e-03,   7.84710314e-03,  -3.06056492e-03,
#         -8.48999097e-03,   2.01048576e-02,  -3.17244216e-03,
#         -2.38706663e-02,   3.29422551e-02,  -2.04169143e-02,
#         -4.13286964e-03,   4.73662784e-03,   3.48850279e-03,
#         -5.55518846e-03,   4.65940411e-03,   1.04018789e-02,
#          2.03111409e-03,  -1.98144706e-02,   2.89274125e-03,
#          5.95448016e-03,  -1.38634958e-02,   2.05201470e-02,
#          1.15192497e-02,  -5.30095028e-03,  -1.91026978e-02,
#          1.03718327e-02,  -1.66821613e-02,  -6.29844075e-03,
#          2.20395171e-02,  -1.45993188e-02,  -3.08091968e-03,
#          1.83868761e-02,  -1.78492040e-02,   1.49663584e-02,
#         -3.21326801e-03,  -5.31599013e-03,   9.56601213e-03,
#          8.85977698e-03,  -1.26959767e-02])

# %%
fig = gcf()
fig.set_size_inches(10,5)

plot(np.insert(y,0,zeros(n)),'k',linewidth=0.5)
plot(x_all[:(m+n-1)],'g',linewidth=0.5)
