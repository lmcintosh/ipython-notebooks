# %%
import numpy as np
import json
from os.path import expanduser

# This is a bit of magic to make matplotlib figures appear inline in the
# notebook rather than in a new window.
# %matplotlib inline
import matplotlib.pyplot as plt

from pylab import rcParams
rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
rcParams['image.interpolation'] = 'nearest'
rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
naturalscene_rf_mapping = '{"function": "naturalscene", "length": 5, "seed": 150, "framerate": 30, "contrast": 1.0, "ndims": [50,50], "imgdir": "images/", "imgext": "*.mat", "jumpevery": 30, "jitter": 0.5}'
whitenoise_repeat = '{"function": "whitenoise", "length": 0.5, "seed": 90, "framerate": 30, "contrast": 1.0, "ndims": [50,50], "dist": "binary"}'
whitenoise_clips = ['{"function": "whitenoise", "length": 5, "seed": %d, "framerate": 30, "contrast": 1.0, "ndims": [50,50], "dist": "binary"}' %(91+i)
                      for i in range(14)]

# %%
naturalscene_rf_mapping
# Out:
# '{"function": "naturalscene", "length": 5, "seed": 150, "framerate": 30, "contrast": 1.0, "ndims": [50,50], "imgdir": "images/", "imgext": "*.mat", "jumpevery": 30, "jitter": 0.5}'

# %%
whitenoise_clips
# Out:
# ['{"function": "whitenoise", "length": 5, "seed": 91, "framerate": 30, "contrast": 1.0, "ndims": [50,50], "dist": "binary"}',
#  '{"function": "whitenoise", "length": 5, "seed": 92, "framerate": 30, "contrast": 1.0, "ndims": [50,50], "dist": "binary"}',
#  '{"function": "whitenoise", "length": 5, "seed": 93, "framerate": 30, "contrast": 1.0, "ndims": [50,50], "dist": "binary"}',
#  '{"function": "whitenoise", "length": 5, "seed": 94, "framerate": 30, "contrast": 1.0, "ndims": [50,50], "dist": "binary"}',
#  '{"function": "whitenoise", "length": 5, "seed": 95, "framerate": 30, "contrast": 1.0, "ndims": [50,50], "dist": "binary"}',
#  '{"function": "whitenoise", "length": 5, "seed": 96, "framerate": 30, "contrast": 1.0, "ndims": [50,50], "dist": "binary"}',
#  '{"function": "whitenoise", "length": 5, "seed": 97, "framerate": 30, "contrast": 1.0, "ndims": [50,50], "dist": "binary"}',
#  '{"function": "whitenoise", "length": 5, "seed": 98, "framerate": 30, "contrast": 1.0, "ndims": [50,50], "dist": "binary"}',
#  '{"function": "whitenoise", "length": 5, "seed": 99, "framerate": 30, "contrast": 1.0, "ndims": [50,50], "dist": "binary"}',
#  '{"function": "whitenoise", "length": 5, "seed": 100, "framerate": 30, "contrast": 1.0, "ndims": [50,50], "dist": "binary"}',
#  '{"function": "whitenoise", "length": 5, "seed": 101, "framerate": 30, "contrast": 1.0, "ndims": [50,50], "dist": "binary"}',
#  '{"function": "whitenoise", "length": 5, "seed": 102, "framerate": 30, "contrast": 1.0, "ndims": [50,50], "dist": "binary"}',
#  '{"function": "whitenoise", "length": 5, "seed": 103, "framerate": 30, "contrast": 1.0, "ndims": [50,50], "dist": "binary"}',
#  '{"function": "whitenoise", "length": 5, "seed": 104, "framerate": 30, "contrast": 1.0, "ndims": [50,50], "dist": "binary"}']

# %%
stimulus_seq = []
stimulus_seq.append(naturalscene_rf_mapping)
# 14 single trials of 5 min each (70 min total)
for block in range(len(whitenoise_clips)):
    stimulus_seq.append(whitenoise_clips[block])
    # 14 * 8 = 112 repeats
    for repeat in range(8):
        stimulus_seq.append(whitenoise_repeat)
stimulus_seq.append(naturalscene_rf_mapping)

# %%
len(stimulus_seq)
# Out:
# 128

# %%
total_length = 5*2 + 14.*8.*.5 + 14*5
total_length
# Out:
# 136.0

# %%
with open('config.json', 'w') as outfile:
    json.dump(stimulus_seq, outfile)

# %%
stimulus_seq
# Out:
# [{'contrast': 1.0,
#   'dist': 'binary',
#   'framerate': 30,
#   'function': 'naturalscene',
#   'length': 5,
#   'ndims': [50, 50],
#   'seed': 150},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 5,
#   'ndims': [50, 50],
#   'seed': 91},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 5,
#   'ndims': [50, 50],
#   'seed': 92},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 5,
#   'ndims': [50, 50],
#   'seed': 93},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 5,
#   'ndims': [50, 50],
#   'seed': 94},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 5,
#   'ndims': [50, 50],
#   'seed': 95},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 5,
#   'ndims': [50, 50],
#   'seed': 96},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 5,
#   'ndims': [50, 50],
#   'seed': 97},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 5,
#   'ndims': [50, 50],
#   'seed': 98},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 5,
#   'ndims': [50, 50],
#   'seed': 99},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 5,
#   'ndims': [50, 50],
#   'seed': 100},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 5,
#   'ndims': [50, 50],
#   'seed': 101},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 5,
#   'ndims': [50, 50],
#   'seed': 102},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 5,
#   'ndims': [50, 50],
#   'seed': 103},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 5,
#   'ndims': [50, 50],
#   'seed': 104},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'framerate': 30,
#   'function': 'whitenoise',
#   'imgdir': 'images/',
#   'imgext': '*.mat',
#   'jitter': 0.5,
#   'jumpevery': 30,
#   'length': 0.5,
#   'ndims': [50, 50],
#   'seed': 90},
#  {'contrast': 1.0,
#   'dist': 'binary',
#   'framerate': 30,
#   'function': 'naturalscene',
#   'length': 5,
#   'ndims': [50, 50],
#   'seed': 150}]

# %% [markdown]
# # try as dictionary, not string

# %%
naturalscene_rf_mapping = {"function": "naturalscene", "length": 5, "seed": 150, "framerate": 30, "contrast": 1.0, "ndims": [50,50], "imgdir": "images/", "imgext": "*.mat", "jumpevery": 30, "jitter": 0.5}
whitenoise_repeat = {"function": "whitenoise", "length": 0.5, "seed": 90, "framerate": 30, "contrast": 1.0, "ndims": [50,50], "dist": "binary"}
whitenoise_clips = [{"function": "whitenoise", "length": 5, "seed": i+91, "framerate": 30, "contrast": 1.0, "ndims": [50,50], "dist": "binary"} for i in range(14)]

# %%
stimulus_seq = []
stimulus_seq.append(naturalscene_rf_mapping)
# 14 single trials of 5 min each (70 min total)
for block in range(len(whitenoise_clips)):
    stimulus_seq.append(whitenoise_clips[block])
    # 14 * 8 = 112 repeats
    for repeat in range(8):
        stimulus_seq.append(whitenoise_repeat)
stimulus_seq.append(naturalscene_rf_mapping)

# %%
with open('config.json', 'w') as outfile:
    json.dump(stimulus_seq, outfile)
