# %% [markdown]
# # Varying speed of the periphery
#
# My idea:  Start with Palmer’s sentiment that, “in a world where objects move, motion detection is an efficient way of encoding the external world.”  Then would we predict that motion that isn’t dominant in the world would be poorly encoded.  I.e., circuits of the retina would be designed for efficiently representing speeds it actually encounters.  These speeds could be represented by a bimodal distribution peaked at object motion (which is captured by OMS cells) and saccadic eye movements (captured by Pablo’s gating result).
#
# Hypothesis: We would have more spikes in between these two modes than we’d expect, because there is a regime where we aren’t suppressing predictable signals and so have to poorly encode the signal.
#
# Pablo’s Experiment:
# Conditions:
# Saccading (square grating motion in periphery),
# Object only (periphery constant, object moving according to OMS protocol),
# G0 (periphery moving in phase and at same speed as object; also in OMS protocol),
# G1 (periphery moving 2x as fast as object)
# G2 (periphery moving 4x)
# G3 (periphery moving 6x)
#
# Note about OMS cells: they are the ones that spike a lot in object-only condition but are completely suppressed in global motion condition (G0).

# %%
cd ~/00_Baccus/
# Out:
# /home/lane/00_Baccus

# %%
import numpy as np
import pyentropy
from matplotlib import *

# %% [markdown]
# ## Import data from Matlab

# %%
import scipy.io
mat = scipy.io.loadmat('110413data.mat')

# %%
mat.keys()
# Out:
# ['framesN',
#  '__function_workspace__',
#  'globalFlag',
#  'frame',
#  'period',
#  'offsetCenter',
#  'peripheryStep',
#  'rate',
#  'seed',
#  'ans',
#  'duration',
#  'newSeed',
#  'times',
#  'yoda',
#  'stimulus_center',
#  'centerStep',
#  'rates',
#  '__version__',
#  'conditions',
#  'peripheryFrame',
#  'None',
#  'FEMPeriphery',
#  'waitframes',
#  'PIXELS_PER_100_MICRONS',
#  'startTime',
#  'checkersSize',
#  'offsetPeriphery',
#  'c',
#  'repeats',
#  'FEMcenter',
#  'i',
#  'cells',
#  '__header__',
#  '__globals__',
#  'r',
#  't',
#  'presentationLength',
#  'endTime',
#  'stimulus_periph']

# %%
stimulus_center = mat['stimulus_center']
stimulus_periph = mat['stimulus_periph']
spikes          = mat['cells']
conditions      = mat['conditions']
startTime       = mat['startTime']
endTime         = mat['endTime']
duration        = mat['duration']
repeats         = mat['repeats']

# %%
stimulus_center.shape
# Out:
# (10, 1000)

# %% [markdown]
# ## Preprocessing

# %%
whole_expt_center = np.zeros((10,10*1000))  # repeats x conditions*time
whole_expt_periph = np.zeros((10,10*1000))
stimulus_center_v = stimulus_center.reshape((1,10*1000))
stimulus_periph_v = stimulus_periph.reshape((1,10*1000))
times             = np.linspace(startTime[0][0],endTime[0][0],size(whole_expt_periph))
#times             = times.reshape((10,10*1000))

for i in xrange(10):
    whole_expt_center[i,:] = stimulus_center_v
    whole_expt_periph[i,:] = stimulus_periph_v

# %%
allneurons = []

for n in xrange(len(spikes)):
    subsampled_spikes = np.zeros(times.shape)  # repeats x subsampled time
    for i in xrange(size(times)-1):
        tmp = spikes[n][0][where(spikes[n][0] < times[i+1])]
        tmp = tmp[where(times[i] <= tmp)]
        subsampled_spikes[i] = len(tmp)
    
    subsampled_spikes = subsampled_spikes.reshape((10,10*1000))
    allneurons.append(subsampled_spikes)

# %%
a = stimulus_center.reshape((1,10*1000))
b = stimulus_periph.reshape((1,10*1000))

# %%
fig = gcf()
fig.set_size_inches((16,4))

subplot(121)
d = plot(b[0])
subplot(122)
d = plot(a[0])

# %% [markdown]
# ## Information functions

# %%
def binaryWordsInformation(spikes,stimulus):
    '''Compute entropy of spike trains with binary words approach.
    
    Spikes and stimulus are both 1-d vertical numpy arrays
    with as many elements as neurons.
    '''
    # Quantize stimulus and
    # align spikes & stim for entropy calculation
    numNeurons = len(spikes)
    spikes     = spikes.flatten()   # get in format (numNeurons,)
    stimulus   = stimulus.flatten() # get in format (numNeurons,)
    if len(np.unique(spikes)) > 2:
        spikes = pyentropy.quantise(spikes, 2, uniform='sampling', minmax=None, centers=True)
        spikes = spikes[0]
    else:
        spikes     = spikes.astype(int) # make integer array from float64 array
    
    stim_quant = pyentropy.quantise(stimulus, 2, uniform='sampling', minmax=None, centers=True)
    system     = pyentropy.DiscreteSystem(spikes, (1,numNeurons), stim_quant[0], (1,numNeurons))
    
    # compute entropies
    system.calculate_entropies(method='plugin', calc=['HX', 'HXY'])
    
    # return information between spikes and stimulus
    return system.I()

# %%
def mutiN(voltage, current, nBins, minV, maxV, minC, maxC):
    '''Function to compute the mutual information between neuron voltage and the input current - with just two bins!
    
    Note that you need to use asarray(V) and asarray(current) to get time slices instead of per-neuron slices'''
    
    # could potentially ask for min, max, and then use linspace to specify bin edges
    binsA = linspace(minV, maxV, nBins+1)
    binsB = linspace(minC, maxC, nBins+1)
    
    # note that in this function's MATLAB counterpart, I explicitly made one bin spiking.
    # here I avoid doing that because I don't force a spike to have a particular voltage,
    # I just call it when it passes threshold on the next iteration
    
    # Counting
    CountsAB, xedges, yedges = histogram2d(squeeze(voltage),squeeze(current), bins=[binsA, binsB])
    CountsA = sum(CountsAB,0) # this sums all the rows, leaving the marginal distribution of voltage
    CountsB = sum(CountsAB,1) # this sums all the cols, leaving the marginal distribution of current
    
    pA  = CountsA.astype(float)/float(sum(CountsA))
    pB  = CountsB.astype(float)/float(sum(CountsB))
    pAB = CountsAB.astype(float)/float(sum(CountsAB))
    
    
    if abs(1 - sum(pA)) > 0.01:
        print 'Probabilities pA do not sum to one ' + str(sum(pA))
    if abs(1 - sum(pB)) > 0.01:
        print 'Probabilities pB do not sum to one ' + str(sum(pB))
    if abs(1 - sum(pAB)) > 0.01:
        print 'Probabilities pAB do not sum to one ' + str(sum(pAB))
    
    
    # Entropies
    HA  = 0.0
    HB  = 0.0
    HAB = 0.0
    
    for prob in pB:
        if prob != 0:
            HB = HB - prob*log2(prob)
    
    for j in xrange(len(pA)):
        if pA[j] != 0:
            HA = HA - pA[j] * log2(pA[j])
            for i in xrange(len(pB)):
                if pAB[i,j] != 0:
                    HAB = HAB - pAB[i,j] * log2(pAB[i,j])
                    
    H = [HA, HB, HAB]
    I = HA + HB - HAB
    
    return H, I

# %% [markdown]
# ## Calculate information for each neuron and condition

# %%
shape(allneurons[0])
# Out:
# (10, 10000)

# %%
i_pred_center = []
i_pred_periph = []

for n in xrange(len(allneurons)):
    binary_response = allneurons[n]
    
    binary_instant_pred_c = np.zeros((whole_expt_center.shape[1]-1,1))
    binary_instant_pred_p = np.zeros((whole_expt_center.shape[1]-1,1))
    
    for t in xrange(whole_expt_center.shape[1]-1):
        binary_instant_pred_c[t] = binaryWordsInformation(binary_response[:,t],whole_expt_center[:,t])
        binary_instant_pred_p[t] = binaryWordsInformation(binary_response[:,t],whole_expt_periph[:,t])
    
    i_pred_center.append(binary_instant_pred_c)
    i_pred_periph.append(binary_instant_pred_p)

# %%
plot(binary_instant_pred_p)

# %%
max(i_pred_center[1])
# Out:
# array([ 0.])

# %%
x = i_pred_center[:][:]

# %%
plot(np.squeeze(x[:][:]))
# Out:
# [<matplotlib.lines.Line2D at 0x1e3b1c50>,
#  <matplotlib.lines.Line2D at 0x1e3b1cd0>,
#  <matplotlib.lines.Line2D at 0x1e3b1e10>,
#  <matplotlib.lines.Line2D at 0x1e3a4510>,
#  <matplotlib.lines.Line2D at 0x1e3a49d0>,
#  <matplotlib.lines.Line2D at 0x1e3a4c10>,
#  <matplotlib.lines.Line2D at 0x1e3a46d0>,
#  <matplotlib.lines.Line2D at 0x28145b90>,
#  <matplotlib.lines.Line2D at 0x242528d0>,
#  <matplotlib.lines.Line2D at 0x1865c110>,
#  <matplotlib.lines.Line2D at 0x1865c390>,
#  <matplotlib.lines.Line2D at 0x1865c550>,
#  <matplotlib.lines.Line2D at 0x1865c710>,
#  <matplotlib.lines.Line2D at 0x1865c8d0>,
#  <matplotlib.lines.Line2D at 0x1e3a8350>,
#  <matplotlib.lines.Line2D at 0x1865cc50>,
#  <matplotlib.lines.Line2D at 0x1865ce10>,
#  <matplotlib.lines.Line2D at 0x1865cfd0>,
#  <matplotlib.lines.Line2D at 0x1e3911d0>,
#  <matplotlib.lines.Line2D at 0x1e391390>,
#  <matplotlib.lines.Line2D at 0x1e391550>,
#  <matplotlib.lines.Line2D at 0x1865cad0>,
#  <matplotlib.lines.Line2D at 0x1e3918d0>,
#  <matplotlib.lines.Line2D at 0x1e391a90>,
#  <matplotlib.lines.Line2D at 0x1e391c50>,
#  <matplotlib.lines.Line2D at 0x1e391e10>,
#  <matplotlib.lines.Line2D at 0x1e391fd0>,
#  <matplotlib.lines.Line2D at 0x1e38d1d0>,
#  <matplotlib.lines.Line2D at 0x1e391750>,
#  <matplotlib.lines.Line2D at 0x1e38d550>,
#  <matplotlib.lines.Line2D at 0x1e38d710>,
#  <matplotlib.lines.Line2D at 0x1e38d8d0>,
#  <matplotlib.lines.Line2D at 0x1e38da90>,
#  <matplotlib.lines.Line2D at 0x1e38dc50>,
#  <matplotlib.lines.Line2D at 0x1e38de10>,
#  <matplotlib.lines.Line2D at 0x1e38dfd0>,
#  <matplotlib.lines.Line2D at 0x18638c50>,
#  <matplotlib.lines.Line2D at 0x18638f10>,
#  <matplotlib.lines.Line2D at 0x18638490>,
#  <matplotlib.lines.Line2D at 0x18638810>,
#  <matplotlib.lines.Line2D at 0x18638410>,
#  <matplotlib.lines.Line2D at 0x18638a90>,
#  <matplotlib.lines.Line2D at 0x18638710>,
#  <matplotlib.lines.Line2D at 0x18638e90>,
#  <matplotlib.lines.Line2D at 0x18638090>,
#  <matplotlib.lines.Line2D at 0x1865d1d0>,
#  <matplotlib.lines.Line2D at 0x1865d390>,
#  <matplotlib.lines.Line2D at 0x1865d550>,
#  <matplotlib.lines.Line2D at 0x1865d710>,
#  <matplotlib.lines.Line2D at 0x186386d0>,
#  <matplotlib.lines.Line2D at 0x1865da90>,
#  <matplotlib.lines.Line2D at 0x1865dc50>,
#  <matplotlib.lines.Line2D at 0x1865de10>,
#  <matplotlib.lines.Line2D at 0x1865dfd0>,
#  <matplotlib.lines.Line2D at 0x1865f1d0>,
#  <matplotlib.lines.Line2D at 0x1865f390>,
#  <matplotlib.lines.Line2D at 0x1865d910>,
#  <matplotlib.lines.Line2D at 0x1865f710>,
#  <matplotlib.lines.Line2D at 0x1865f8d0>,
#  <matplotlib.lines.Line2D at 0x1865fa90>,
#  <matplotlib.lines.Line2D at 0x1865fc50>,
#  <matplotlib.lines.Line2D at 0x1865fe10>,
#  <matplotlib.lines.Line2D at 0x1865ffd0>,
#  <matplotlib.lines.Line2D at 0x1865f590>,
#  <matplotlib.lines.Line2D at 0x18664390>,
#  <matplotlib.lines.Line2D at 0x18664550>,
#  <matplotlib.lines.Line2D at 0x18664710>,
#  <matplotlib.lines.Line2D at 0x186648d0>,
#  <matplotlib.lines.Line2D at 0x18664a90>,
#  <matplotlib.lines.Line2D at 0x18664c50>,
#  <matplotlib.lines.Line2D at 0x18664e10>,
#  <matplotlib.lines.Line2D at 0x18664fd0>,
#  <matplotlib.lines.Line2D at 0x186391d0>,
#  <matplotlib.lines.Line2D at 0x18639390>,
#  <matplotlib.lines.Line2D at 0x18639550>,
#  <matplotlib.lines.Line2D at 0x18639710>,
#  <matplotlib.lines.Line2D at 0x186398d0>,
#  <matplotlib.lines.Line2D at 0x18664e50>,
#  <matplotlib.lines.Line2D at 0x18639c50>,
#  <matplotlib.lines.Line2D at 0x18639e10>,
#  <matplotlib.lines.Line2D at 0x18639fd0>,
#  <matplotlib.lines.Line2D at 0x1863a1d0>,
#  <matplotlib.lines.Line2D at 0x1863a390>,
#  <matplotlib.lines.Line2D at 0x1863a550>,
#  <matplotlib.lines.Line2D at 0x18639ad0>,
#  <matplotlib.lines.Line2D at 0x1863a8d0>,
#  <matplotlib.lines.Line2D at 0x1863aa90>,
#  <matplotlib.lines.Line2D at 0x1863ac50>,
#  <matplotlib.lines.Line2D at 0x1863ae10>,
#  <matplotlib.lines.Line2D at 0x1863afd0>,
#  <matplotlib.lines.Line2D at 0x186421d0>,
#  <matplotlib.lines.Line2D at 0x1863a750>,
#  <matplotlib.lines.Line2D at 0x18642550>,
#  <matplotlib.lines.Line2D at 0x18642710>,
#  <matplotlib.lines.Line2D at 0x186428d0>,
#  <matplotlib.lines.Line2D at 0x18642a90>,
#  <matplotlib.lines.Line2D at 0x18642c50>,
#  <matplotlib.lines.Line2D at 0x18642e10>,
#  <matplotlib.lines.Line2D at 0x18642fd0>,
#  <matplotlib.lines.Line2D at 0x186411d0>,
#  <matplotlib.lines.Line2D at 0x18641390>,
#  <matplotlib.lines.Line2D at 0x18641550>,
#  <matplotlib.lines.Line2D at 0x18641710>,
#  <matplotlib.lines.Line2D at 0x186418d0>,
#  <matplotlib.lines.Line2D at 0x18641a90>,
#  <matplotlib.lines.Line2D at 0x18641c50>,
#  <matplotlib.lines.Line2D at 0x18641e10>,
#  <matplotlib.lines.Line2D at 0x18641fd0>,
#  <matplotlib.lines.Line2D at 0x186451d0>,
#  <matplotlib.lines.Line2D at 0x18645390>,
#  <matplotlib.lines.Line2D at 0x18645550>,
#  <matplotlib.lines.Line2D at 0x18645710>,
#  <matplotlib.lines.Line2D at 0x18641c90>,
#  <matplotlib.lines.Line2D at 0x18645a90>,
#  <matplotlib.lines.Line2D at 0x18645c50>,
#  <matplotlib.lines.Line2D at 0x18645e10>,
#  <matplotlib.lines.Line2D at 0x18645fd0>,
#  <matplotlib.lines.Line2D at 0x186351d0>,
#  <matplotlib.lines.Line2D at 0x18635390>,
#  <matplotlib.lines.Line2D at 0x18645910>,
#  <matplotlib.lines.Line2D at 0x18635710>,
#  <matplotlib.lines.Line2D at 0x186358d0>,
#  <matplotlib.lines.Line2D at 0x18635a90>,
#  <matplotlib.lines.Line2D at 0x18635c50>,
#  <matplotlib.lines.Line2D at 0x18635e10>,
#  <matplotlib.lines.Line2D at 0x18635fd0>,
#  <matplotlib.lines.Line2D at 0x18635590>,
#  <matplotlib.lines.Line2D at 0x18661390>,
#  <matplotlib.lines.Line2D at 0x18661550>,
#  <matplotlib.lines.Line2D at 0x18661710>,
#  <matplotlib.lines.Line2D at 0x186618d0>,
#  <matplotlib.lines.Line2D at 0x18661a90>,
#  <matplotlib.lines.Line2D at 0x18661c50>,
#  <matplotlib.lines.Line2D at 0x18661e10>,
#  <matplotlib.lines.Line2D at 0x18661fd0>,
#  <matplotlib.lines.Line2D at 0x186531d0>,
#  <matplotlib.lines.Line2D at 0x18653390>,
#  <matplotlib.lines.Line2D at 0x18653550>,
#  <matplotlib.lines.Line2D at 0x18653710>,
#  <matplotlib.lines.Line2D at 0x186538d0>,
#  <matplotlib.lines.Line2D at 0x18661e50>,
#  <matplotlib.lines.Line2D at 0x18653c50>,
#  <matplotlib.lines.Line2D at 0x18653e10>,
#  <matplotlib.lines.Line2D at 0x18653fd0>,
#  <matplotlib.lines.Line2D at 0x186321d0>,
#  <matplotlib.lines.Line2D at 0x18632390>,
#  <matplotlib.lines.Line2D at 0x18632550>,
#  <matplotlib.lines.Line2D at 0x18653ad0>,
#  <matplotlib.lines.Line2D at 0x186328d0>,
#  <matplotlib.lines.Line2D at 0x18632a90>,
#  <matplotlib.lines.Line2D at 0x18632c50>,
#  <matplotlib.lines.Line2D at 0x18632e10>,
#  <matplotlib.lines.Line2D at 0x18632fd0>,
#  <matplotlib.lines.Line2D at 0x186651d0>,
#  <matplotlib.lines.Line2D at 0x18632750>,
#  <matplotlib.lines.Line2D at 0x18665550>,
#  <matplotlib.lines.Line2D at 0x18665710>,
#  <matplotlib.lines.Line2D at 0x186658d0>,
#  <matplotlib.lines.Line2D at 0x18665a90>,
#  <matplotlib.lines.Line2D at 0x18665c50>,
#  <matplotlib.lines.Line2D at 0x18665e10>,
#  <matplotlib.lines.Line2D at 0x18665fd0>,
#  <matplotlib.lines.Line2D at 0x1862e1d0>,
#  <matplotlib.lines.Line2D at 0x1862e390>,
#  <matplotlib.lines.Line2D at 0x1862e550>,
#  <matplotlib.lines.Line2D at 0x1862e710>,
#  <matplotlib.lines.Line2D at 0x1862e8d0>,
#  <matplotlib.lines.Line2D at 0x1862ea90>,
#  <matplotlib.lines.Line2D at 0x1862ec50>,
#  <matplotlib.lines.Line2D at 0x1862ee10>,
#  <matplotlib.lines.Line2D at 0x1862efd0>,
#  <matplotlib.lines.Line2D at 0x186621d0>,
#  <matplotlib.lines.Line2D at 0x18662390>,
#  <matplotlib.lines.Line2D at 0x18662550>,
#  <matplotlib.lines.Line2D at 0x18662710>,
#  <matplotlib.lines.Line2D at 0x1862ec90>,
#  <matplotlib.lines.Line2D at 0x18662a90>,
#  <matplotlib.lines.Line2D at 0x18662c50>,
#  <matplotlib.lines.Line2D at 0x18662e10>,
#  <matplotlib.lines.Line2D at 0x18662fd0>,
#  <matplotlib.lines.Line2D at 0x186281d0>,
#  <matplotlib.lines.Line2D at 0x18628390>,
#  <matplotlib.lines.Line2D at 0x18662910>,
#  <matplotlib.lines.Line2D at 0x18628710>,
#  <matplotlib.lines.Line2D at 0x186288d0>,
#  <matplotlib.lines.Line2D at 0x18628a90>,
#  <matplotlib.lines.Line2D at 0x18628c50>,
#  <matplotlib.lines.Line2D at 0x18628e10>,
#  <matplotlib.lines.Line2D at 0x18628fd0>,
#  <matplotlib.lines.Line2D at 0x18628590>,
#  <matplotlib.lines.Line2D at 0x1864d390>,
#  <matplotlib.lines.Line2D at 0x1864d550>,
#  <matplotlib.lines.Line2D at 0x1864d710>,
#  <matplotlib.lines.Line2D at 0x1864d8d0>,
#  <matplotlib.lines.Line2D at 0x1864da90>,
#  <matplotlib.lines.Line2D at 0x1864dc50>,
#  <matplotlib.lines.Line2D at 0x1864de10>,
#  <matplotlib.lines.Line2D at 0x1864dfd0>,
#  <matplotlib.lines.Line2D at 0x1e1531d0>,
#  <matplotlib.lines.Line2D at 0x1e153390>,
#  <matplotlib.lines.Line2D at 0x1e153550>,
#  <matplotlib.lines.Line2D at 0x1e153710>,
#  <matplotlib.lines.Line2D at 0x1e1538d0>,
#  <matplotlib.lines.Line2D at 0x1864de50>,
#  <matplotlib.lines.Line2D at 0x1e153c50>,
#  <matplotlib.lines.Line2D at 0x1e153e10>,
#  <matplotlib.lines.Line2D at 0x1e153fd0>,
#  <matplotlib.lines.Line2D at 0x1e16d1d0>,
#  <matplotlib.lines.Line2D at 0x1e16d390>,
#  <matplotlib.lines.Line2D at 0x1e16d550>,
#  <matplotlib.lines.Line2D at 0x1e153ad0>,
#  <matplotlib.lines.Line2D at 0x1e16d8d0>,
#  <matplotlib.lines.Line2D at 0x1e16da90>,
#  <matplotlib.lines.Line2D at 0x1e16dc50>,
#  <matplotlib.lines.Line2D at 0x1e16de10>,
#  <matplotlib.lines.Line2D at 0x1e16dfd0>,
#  <matplotlib.lines.Line2D at 0x1e17e1d0>,
#  <matplotlib.lines.Line2D at 0x1e16d750>,
#  <matplotlib.lines.Line2D at 0x1e17e550>,
#  <matplotlib.lines.Line2D at 0x1e17e710>,
#  <matplotlib.lines.Line2D at 0x1e17e8d0>,
#  <matplotlib.lines.Line2D at 0x1e17ea90>,
#  <matplotlib.lines.Line2D at 0x1e17ec50>,
#  <matplotlib.lines.Line2D at 0x1e17ee10>,
#  <matplotlib.lines.Line2D at 0x1e17efd0>,
#  <matplotlib.lines.Line2D at 0x1e1721d0>,
#  <matplotlib.lines.Line2D at 0x1e172390>,
#  <matplotlib.lines.Line2D at 0x1e172550>,
#  <matplotlib.lines.Line2D at 0x1e172710>,
#  <matplotlib.lines.Line2D at 0x1863c9d0>,
#  <matplotlib.lines.Line2D at 0x1863f5d0>,
#  <matplotlib.lines.Line2D at 0x1863f310>,
#  <matplotlib.lines.Line2D at 0x186279d0>,
#  <matplotlib.lines.Line2D at 0x1864f5d0>,
#  <matplotlib.lines.Line2D at 0x1864f1d0>,
#  <matplotlib.lines.Line2D at 0x1865b6d0>,
#  <matplotlib.lines.Line2D at 0x1e394910>,
#  <matplotlib.lines.Line2D at 0x1e38a350>,
#  <matplotlib.lines.Line2D at 0x1e3a0a50>,
#  <matplotlib.lines.Line2D at 0x1e38ab90>,
#  <matplotlib.lines.Line2D at 0x1e172850>,
#  <matplotlib.lines.Line2D at 0x1e1729d0>,
#  <matplotlib.lines.Line2D at 0x1e172b50>,
#  <matplotlib.lines.Line2D at 0x1e172cd0>,
#  <matplotlib.lines.Line2D at 0x1e172e50>,
#  <matplotlib.lines.Line2D at 0x1e172fd0>,
#  <matplotlib.lines.Line2D at 0x1e149190>,
#  <matplotlib.lines.Line2D at 0x1e149310>,
#  <matplotlib.lines.Line2D at 0x1e149490>,
#  <matplotlib.lines.Line2D at 0x1e149610>,
#  <matplotlib.lines.Line2D at 0x1e149790>,
#  <matplotlib.lines.Line2D at 0x1e149910>,
#  <matplotlib.lines.Line2D at 0x1e149a90>,
#  <matplotlib.lines.Line2D at 0x1e149c10>,
#  <matplotlib.lines.Line2D at 0x1e149d90>,
#  <matplotlib.lines.Line2D at 0x1e149f10>,
#  <matplotlib.lines.Line2D at 0x1e1670d0>,
#  <matplotlib.lines.Line2D at 0x1e167250>,
#  <matplotlib.lines.Line2D at 0x1e167410>,
#  <matplotlib.lines.Line2D at 0x1e149ad0>,
#  <matplotlib.lines.Line2D at 0x1e167790>,
#  <matplotlib.lines.Line2D at 0x1e167950>,
#  <matplotlib.lines.Line2D at 0x1e167b10>,
#  <matplotlib.lines.Line2D at 0x1e167cd0>,
#  <matplotlib.lines.Line2D at 0x1e167e90>,
#  <matplotlib.lines.Line2D at 0x1e146090>,
#  <matplotlib.lines.Line2D at 0x1e167610>,
#  <matplotlib.lines.Line2D at 0x1e146410>,
#  <matplotlib.lines.Line2D at 0x1e1465d0>,
#  <matplotlib.lines.Line2D at 0x1e146790>,
#  <matplotlib.lines.Line2D at 0x1e146950>,
#  <matplotlib.lines.Line2D at 0x1e146b10>,
#  <matplotlib.lines.Line2D at 0x1e146cd0>,
#  <matplotlib.lines.Line2D at 0x1e146e90>,
#  <matplotlib.lines.Line2D at 0x1e14a090>,
#  <matplotlib.lines.Line2D at 0x1e14a250>,
#  <matplotlib.lines.Line2D at 0x1e14a410>,
#  <matplotlib.lines.Line2D at 0x1e14a5d0>,
#  <matplotlib.lines.Line2D at 0x1e14a790>,
#  <matplotlib.lines.Line2D at 0x1e14a950>,
#  <matplotlib.lines.Line2D at 0x1e146ed0>,
#  <matplotlib.lines.Line2D at 0x1e14acd0>,
#  <matplotlib.lines.Line2D at 0x1e14ae90>,
#  <matplotlib.lines.Line2D at 0x1e178090>,
#  <matplotlib.lines.Line2D at 0x1e178250>,
#  <matplotlib.lines.Line2D at 0x1e178410>,
#  <matplotlib.lines.Line2D at 0x1e1785d0>,
#  <matplotlib.lines.Line2D at 0x1e14ab50>,
#  <matplotlib.lines.Line2D at 0x1e178950>,
#  <matplotlib.lines.Line2D at 0x1e178b10>,
#  <matplotlib.lines.Line2D at 0x1e178cd0>,
#  <matplotlib.lines.Line2D at 0x1e178e90>,
#  <matplotlib.lines.Line2D at 0x1e147090>,
#  <matplotlib.lines.Line2D at 0x1e147250>,
#  <matplotlib.lines.Line2D at 0x1e1787d0>,
#  <matplotlib.lines.Line2D at 0x1e1475d0>,
#  <matplotlib.lines.Line2D at 0x1e147790>,
#  <matplotlib.lines.Line2D at 0x1e147950>,
#  <matplotlib.lines.Line2D at 0x1e147b10>,
#  <matplotlib.lines.Line2D at 0x1e147cd0>,
#  <matplotlib.lines.Line2D at 0x1e147e90>,
#  <matplotlib.lines.Line2D at 0x1e147450>,
#  <matplotlib.lines.Line2D at 0x1e15c250>,
#  <matplotlib.lines.Line2D at 0x1e15c410>,
#  <matplotlib.lines.Line2D at 0x1e15c5d0>,
#  <matplotlib.lines.Line2D at 0x1e15c790>,
#  <matplotlib.lines.Line2D at 0x1e15c950>,
#  <matplotlib.lines.Line2D at 0x1e15cb10>,
#  <matplotlib.lines.Line2D at 0x1e15ccd0>,
#  <matplotlib.lines.Line2D at 0x1e15ce90>,
#  <matplotlib.lines.Line2D at 0x1e182090>,
#  <matplotlib.lines.Line2D at 0x1e182250>,
#  <matplotlib.lines.Line2D at 0x1e182410>,
#  <matplotlib.lines.Line2D at 0x1e1825d0>,
#  <matplotlib.lines.Line2D at 0x1e182790>,
#  <matplotlib.lines.Line2D at 0x1e15cd10>,
#  <matplotlib.lines.Line2D at 0x1e182b10>,
#  <matplotlib.lines.Line2D at 0x1e182cd0>,
#  <matplotlib.lines.Line2D at 0x1e182e90>,
#  <matplotlib.lines.Line2D at 0x1e17f090>,
#  <matplotlib.lines.Line2D at 0x1e17f250>,
#  <matplotlib.lines.Line2D at 0x1e17f410>,
#  <matplotlib.lines.Line2D at 0x1e182990>,
#  <matplotlib.lines.Line2D at 0x1e17f790>,
#  <matplotlib.lines.Line2D at 0x1e17f950>,
#  <matplotlib.lines.Line2D at 0x1e17fb10>,
#  <matplotlib.lines.Line2D at 0x1e17fcd0>,
#  <matplotlib.lines.Line2D at 0x1e17fe90>,
#  <matplotlib.lines.Line2D at 0x1e176090>,
#  <matplotlib.lines.Line2D at 0x1e17f610>,
#  <matplotlib.lines.Line2D at 0x1e176410>,
#  <matplotlib.lines.Line2D at 0x1e1765d0>,
#  <matplotlib.lines.Line2D at 0x1e176790>,
#  <matplotlib.lines.Line2D at 0x1e176950>,
#  <matplotlib.lines.Line2D at 0x1e176b10>,
#  <matplotlib.lines.Line2D at 0x1e176cd0>,
#  <matplotlib.lines.Line2D at 0x1e176e90>,
#  <matplotlib.lines.Line2D at 0x1e17c090>,
#  <matplotlib.lines.Line2D at 0x1e17c250>,
#  <matplotlib.lines.Line2D at 0x1e17c410>,
#  <matplotlib.lines.Line2D at 0x1e17c5d0>,
#  <matplotlib.lines.Line2D at 0x1e17c790>,
#  <matplotlib.lines.Line2D at 0x1e17c950>,
#  <matplotlib.lines.Line2D at 0x1e176ed0>,
#  <matplotlib.lines.Line2D at 0x1e17ccd0>,
#  <matplotlib.lines.Line2D at 0x1e17ce90>,
#  <matplotlib.lines.Line2D at 0x1e17a090>,
#  <matplotlib.lines.Line2D at 0x1e17a250>,
#  <matplotlib.lines.Line2D at 0x1e17a410>,
#  <matplotlib.lines.Line2D at 0x1e17a5d0>,
#  <matplotlib.lines.Line2D at 0x1e17cb50>,
#  <matplotlib.lines.Line2D at 0x1e17a950>,
#  <matplotlib.lines.Line2D at 0x1e17ab10>,
#  <matplotlib.lines.Line2D at 0x1e17acd0>,
#  <matplotlib.lines.Line2D at 0x1e17ae90>,
#  <matplotlib.lines.Line2D at 0x1e155090>,
#  <matplotlib.lines.Line2D at 0x1e155250>,
#  <matplotlib.lines.Line2D at 0x1e17a7d0>,
#  <matplotlib.lines.Line2D at 0x1e1555d0>,
#  <matplotlib.lines.Line2D at 0x1e155790>,
#  <matplotlib.lines.Line2D at 0x1e155950>,
#  <matplotlib.lines.Line2D at 0x1e155b10>,
#  <matplotlib.lines.Line2D at 0x1e155cd0>,
#  <matplotlib.lines.Line2D at 0x1e155e90>,
#  <matplotlib.lines.Line2D at 0x1e155450>,
#  <matplotlib.lines.Line2D at 0x1e163250>,
#  <matplotlib.lines.Line2D at 0x1e163410>,
#  <matplotlib.lines.Line2D at 0x1e1635d0>,
#  <matplotlib.lines.Line2D at 0x1e163790>,
#  <matplotlib.lines.Line2D at 0x1e163950>,
#  <matplotlib.lines.Line2D at 0x1e163b10>,
#  <matplotlib.lines.Line2D at 0x1e163cd0>,
#  <matplotlib.lines.Line2D at 0x1e163e90>,
#  <matplotlib.lines.Line2D at 0x1e15e090>,
#  <matplotlib.lines.Line2D at 0x1e15e250>,
#  <matplotlib.lines.Line2D at 0x1e15e410>,
#  <matplotlib.lines.Line2D at 0x1e15e5d0>,
#  <matplotlib.lines.Line2D at 0x1e15e790>,
#  <matplotlib.lines.Line2D at 0x1e163d10>,
#  <matplotlib.lines.Line2D at 0x1e15eb10>,
#  <matplotlib.lines.Line2D at 0x1e15ecd0>,
#  <matplotlib.lines.Line2D at 0x1e15ee90>,
#  <matplotlib.lines.Line2D at 0x1e16c090>,
#  <matplotlib.lines.Line2D at 0x1e16c250>,
#  <matplotlib.lines.Line2D at 0x1e16c410>,
#  <matplotlib.lines.Line2D at 0x1e15e990>,
#  <matplotlib.lines.Line2D at 0x1e16c790>,
#  <matplotlib.lines.Line2D at 0x1e16c950>,
#  <matplotlib.lines.Line2D at 0x1e16cb10>,
#  <matplotlib.lines.Line2D at 0x1e16ccd0>,
#  <matplotlib.lines.Line2D at 0x1e16ce90>,
#  <matplotlib.lines.Line2D at 0x1e169090>,
#  <matplotlib.lines.Line2D at 0x1e16c610>,
#  <matplotlib.lines.Line2D at 0x1e169410>,
#  <matplotlib.lines.Line2D at 0x1e1695d0>,
#  <matplotlib.lines.Line2D at 0x1e169790>,
#  <matplotlib.lines.Line2D at 0x1e169950>,
#  <matplotlib.lines.Line2D at 0x1e169b10>,
#  <matplotlib.lines.Line2D at 0x1e169cd0>,
#  <matplotlib.lines.Line2D at 0x1e169e90>,
#  <matplotlib.lines.Line2D at 0x1e165090>,
#  <matplotlib.lines.Line2D at 0x1e165250>,
#  <matplotlib.lines.Line2D at 0x1e165410>,
#  <matplotlib.lines.Line2D at 0x1e1655d0>,
#  <matplotlib.lines.Line2D at 0x1e165790>,
#  <matplotlib.lines.Line2D at 0x1e165950>,
#  <matplotlib.lines.Line2D at 0x1e169ed0>,
#  <matplotlib.lines.Line2D at 0x1e165cd0>,
#  <matplotlib.lines.Line2D at 0x1e165e90>,
#  <matplotlib.lines.Line2D at 0x1e16a090>,
#  <matplotlib.lines.Line2D at 0x1e16a250>,
#  <matplotlib.lines.Line2D at 0x1e16a410>,
#  <matplotlib.lines.Line2D at 0x1e16a5d0>,
#  <matplotlib.lines.Line2D at 0x1e165b50>,
#  <matplotlib.lines.Line2D at 0x1e16a950>,
#  <matplotlib.lines.Line2D at 0x1e16ab10>,
#  <matplotlib.lines.Line2D at 0x1e16acd0>,
#  <matplotlib.lines.Line2D at 0x1e16ae90>,
#  <matplotlib.lines.Line2D at 0x1e16f090>,
#  <matplotlib.lines.Line2D at 0x1e16f250>,
#  <matplotlib.lines.Line2D at 0x1e16a7d0>,
#  <matplotlib.lines.Line2D at 0x1e16f5d0>,
#  <matplotlib.lines.Line2D at 0x1e16f790>,
#  <matplotlib.lines.Line2D at 0x1e16f950>,
#  <matplotlib.lines.Line2D at 0x1e16fb10>,
#  <matplotlib.lines.Line2D at 0x1e16fcd0>,
#  <matplotlib.lines.Line2D at 0x1e16fe90>,
#  <matplotlib.lines.Line2D at 0x1e16f450>,
#  <matplotlib.lines.Line2D at 0x1dd03250>,
#  <matplotlib.lines.Line2D at 0x1dd03410>,
#  <matplotlib.lines.Line2D at 0x1dd035d0>,
#  <matplotlib.lines.Line2D at 0x1dd03790>,
#  <matplotlib.lines.Line2D at 0x1dd03950>,
#  <matplotlib.lines.Line2D at 0x1dd03b10>,
#  <matplotlib.lines.Line2D at 0x1dd03cd0>,
#  <matplotlib.lines.Line2D at 0x1dd03e90>,
#  <matplotlib.lines.Line2D at 0x1dd19090>,
#  <matplotlib.lines.Line2D at 0x1dd19250>,
#  <matplotlib.lines.Line2D at 0x1dd19410>,
#  <matplotlib.lines.Line2D at 0x1dd195d0>,
#  <matplotlib.lines.Line2D at 0x1dd19790>,
#  <matplotlib.lines.Line2D at 0x1dd03d10>,
#  <matplotlib.lines.Line2D at 0x1dd19b10>,
#  <matplotlib.lines.Line2D at 0x1dd19cd0>,
#  <matplotlib.lines.Line2D at 0x1dd19e90>,
#  <matplotlib.lines.Line2D at 0x1dcf3090>,
#  <matplotlib.lines.Line2D at 0x1dcf3250>,
#  <matplotlib.lines.Line2D at 0x1dcf3410>,
#  <matplotlib.lines.Line2D at 0x1dd19990>,
#  <matplotlib.lines.Line2D at 0x1dcf3790>,
#  <matplotlib.lines.Line2D at 0x1dcf3950>,
#  <matplotlib.lines.Line2D at 0x1dcf3b10>,
#  <matplotlib.lines.Line2D at 0x1dcf3cd0>,
#  <matplotlib.lines.Line2D at 0x1dcf3e90>,
#  <matplotlib.lines.Line2D at 0x1dcdc090>,
#  <matplotlib.lines.Line2D at 0x1dcf3610>,
#  <matplotlib.lines.Line2D at 0x1dcdc410>,
#  <matplotlib.lines.Line2D at 0x1dcdc5d0>,
#  <matplotlib.lines.Line2D at 0x1dcdc790>,
#  <matplotlib.lines.Line2D at 0x1dcdc950>,
#  <matplotlib.lines.Line2D at 0x1dcdcb10>,
#  <matplotlib.lines.Line2D at 0x1dcdccd0>,
#  <matplotlib.lines.Line2D at 0x1dcdce90>,
#  <matplotlib.lines.Line2D at 0x1dd0d090>,
#  <matplotlib.lines.Line2D at 0x1dd0d250>,
#  <matplotlib.lines.Line2D at 0x1dd0d410>,
#  <matplotlib.lines.Line2D at 0x1dd0d5d0>,
#  <matplotlib.lines.Line2D at 0x1dd0d790>,
#  <matplotlib.lines.Line2D at 0x1dd0d950>,
#  <matplotlib.lines.Line2D at 0x1dcdced0>,
#  <matplotlib.lines.Line2D at 0x1dd0dcd0>,
#  <matplotlib.lines.Line2D at 0x1dd0de90>,
#  <matplotlib.lines.Line2D at 0x1dd05090>,
#  <matplotlib.lines.Line2D at 0x1dd05250>,
#  <matplotlib.lines.Line2D at 0x1dd05410>,
#  <matplotlib.lines.Line2D at 0x1dd055d0>,
#  <matplotlib.lines.Line2D at 0x1dd0db50>,
#  <matplotlib.lines.Line2D at 0x1dd05950>,
#  <matplotlib.lines.Line2D at 0x1dd05b10>,
#  <matplotlib.lines.Line2D at 0x1dd05cd0>,
#  <matplotlib.lines.Line2D at 0x1dd05e90>,
#  <matplotlib.lines.Line2D at 0x1dcfb090>,
#  <matplotlib.lines.Line2D at 0x1dcfb250>,
#  <matplotlib.lines.Line2D at 0x1dd057d0>,
#  <matplotlib.lines.Line2D at 0x1dcfb5d0>,
#  <matplotlib.lines.Line2D at 0x1dcfb790>,
#  <matplotlib.lines.Line2D at 0x1dcfb950>,
#  <matplotlib.lines.Line2D at 0x1dcfbb10>,
#  <matplotlib.lines.Line2D at 0x1dcfbcd0>,
#  <matplotlib.lines.Line2D at 0x1dcfbe90>,
#  <matplotlib.lines.Line2D at 0x1dcfb450>,
#  <matplotlib.lines.Line2D at 0x1dce8250>,
#  <matplotlib.lines.Line2D at 0x1dce8410>,
#  <matplotlib.lines.Line2D at 0x1dce85d0>,
#  <matplotlib.lines.Line2D at 0x1dce8790>,
#  <matplotlib.lines.Line2D at 0x1dce8950>,
#  <matplotlib.lines.Line2D at 0x1dce8b10>,
#  <matplotlib.lines.Line2D at 0x1dce8cd0>,
#  <matplotlib.lines.Line2D at 0x1dce8e90>,
#  <matplotlib.lines.Line2D at 0x1dce1090>,
#  <matplotlib.lines.Line2D at 0x1dce1250>,
#  <matplotlib.lines.Line2D at 0x1dce1410>,
#  <matplotlib.lines.Line2D at 0x1dce15d0>,
#  <matplotlib.lines.Line2D at 0x1dce1790>,
#  <matplotlib.lines.Line2D at 0x1dce8d10>,
#  <matplotlib.lines.Line2D at 0x1dce1b10>,
#  <matplotlib.lines.Line2D at 0x1dce1cd0>,
#  <matplotlib.lines.Line2D at 0x1dce1e90>,
#  <matplotlib.lines.Line2D at 0x1dcee090>,
#  <matplotlib.lines.Line2D at 0x1dcee250>,
#  <matplotlib.lines.Line2D at 0x1dcee410>,
#  <matplotlib.lines.Line2D at 0x1dce1990>,
#  <matplotlib.lines.Line2D at 0x1dcee790>,
#  <matplotlib.lines.Line2D at 0x1dcee950>,
#  <matplotlib.lines.Line2D at 0x1dceeb10>,
#  <matplotlib.lines.Line2D at 0x1dceecd0>,
#  <matplotlib.lines.Line2D at 0x1dceee90>,
#  <matplotlib.lines.Line2D at 0x1dd0f090>,
#  <matplotlib.lines.Line2D at 0x1dcee610>,
#  <matplotlib.lines.Line2D at 0x1dd0f410>,
#  <matplotlib.lines.Line2D at 0x1dd0f5d0>,
#  <matplotlib.lines.Line2D at 0x1dd0f790>,
#  <matplotlib.lines.Line2D at 0x1dd0f950>,
#  <matplotlib.lines.Line2D at 0x1dd0fb10>,
#  <matplotlib.lines.Line2D at 0x1dd0fcd0>,
#  <matplotlib.lines.Line2D at 0x1dd0fe90>,
#  <matplotlib.lines.Line2D at 0x1dd02090>,
#  <matplotlib.lines.Line2D at 0x1dd02250>,
#  <matplotlib.lines.Line2D at 0x1dd02410>,
#  <matplotlib.lines.Line2D at 0x1dd025d0>,
#  <matplotlib.lines.Line2D at 0x1dd02790>,
#  <matplotlib.lines.Line2D at 0x1dd02950>,
#  <matplotlib.lines.Line2D at 0x1dd0fed0>,
#  <matplotlib.lines.Line2D at 0x1dd02cd0>,
#  <matplotlib.lines.Line2D at 0x1dd02e90>,
#  <matplotlib.lines.Line2D at 0x1dcf2090>,
#  <matplotlib.lines.Line2D at 0x1dcf2250>,
#  <matplotlib.lines.Line2D at 0x1dcf2410>,
#  <matplotlib.lines.Line2D at 0x1dcf25d0>,
#  <matplotlib.lines.Line2D at 0x1dd02b50>,
#  <matplotlib.lines.Line2D at 0x1dcf2950>,
#  <matplotlib.lines.Line2D at 0x1dcf2b10>,
#  <matplotlib.lines.Line2D at 0x1dcf2cd0>,
#  <matplotlib.lines.Line2D at 0x1dcf2e90>,
#  <matplotlib.lines.Line2D at 0x1dd12090>,
#  <matplotlib.lines.Line2D at 0x1dd12250>,
#  <matplotlib.lines.Line2D at 0x1dcf27d0>,
#  <matplotlib.lines.Line2D at 0x1dd125d0>,
#  <matplotlib.lines.Line2D at 0x1dd12790>,
#  <matplotlib.lines.Line2D at 0x1dd12950>,
#  <matplotlib.lines.Line2D at 0x1dd12b10>,
#  <matplotlib.lines.Line2D at 0x1dd12cd0>,
#  <matplotlib.lines.Line2D at 0x1dd12e90>,
#  <matplotlib.lines.Line2D at 0x1dd12450>,
#  <matplotlib.lines.Line2D at 0x1dd14250>,
#  <matplotlib.lines.Line2D at 0x1dd14410>,
#  <matplotlib.lines.Line2D at 0x1dd145d0>,
#  <matplotlib.lines.Line2D at 0x1dd14790>,
#  <matplotlib.lines.Line2D at 0x1dd14950>,
#  <matplotlib.lines.Line2D at 0x1dd14b10>,
#  <matplotlib.lines.Line2D at 0x1dd14cd0>,
#  <matplotlib.lines.Line2D at 0x1dd14e90>,
#  <matplotlib.lines.Line2D at 0x1dcff090>,
#  <matplotlib.lines.Line2D at 0x1dcff250>,
#  <matplotlib.lines.Line2D at 0x1dcff410>,
#  <matplotlib.lines.Line2D at 0x1dcff5d0>,
#  <matplotlib.lines.Line2D at 0x1dcff790>,
#  <matplotlib.lines.Line2D at 0x1dd14d10>,
#  <matplotlib.lines.Line2D at 0x1dcffb10>,
#  <matplotlib.lines.Line2D at 0x1dcffcd0>,
#  <matplotlib.lines.Line2D at 0x1dcffe90>,
#  <matplotlib.lines.Line2D at 0x1dcde090>,
#  <matplotlib.lines.Line2D at 0x1dcde250>,
#  <matplotlib.lines.Line2D at 0x1dcde410>,
#  <matplotlib.lines.Line2D at 0x1dcff990>,
#  <matplotlib.lines.Line2D at 0x1dcde790>,
#  <matplotlib.lines.Line2D at 0x1dcde950>,
#  <matplotlib.lines.Line2D at 0x1dcdeb10>,
#  <matplotlib.lines.Line2D at 0x1dcdecd0>,
#  <matplotlib.lines.Line2D at 0x1dcdee90>,
#  <matplotlib.lines.Line2D at 0x1dcfd090>,
#  <matplotlib.lines.Line2D at 0x1dcde610>,
#  <matplotlib.lines.Line2D at 0x1dcfd410>,
#  <matplotlib.lines.Line2D at 0x1dcfd5d0>,
#  <matplotlib.lines.Line2D at 0x1dcfd790>,
#  <matplotlib.lines.Line2D at 0x1dcfd950>,
#  <matplotlib.lines.Line2D at 0x1dcfdb10>,
#  <matplotlib.lines.Line2D at 0x1dcfdcd0>,
#  <matplotlib.lines.Line2D at 0x1dcfde90>,
#  <matplotlib.lines.Line2D at 0x1dcfc090>,
#  <matplotlib.lines.Line2D at 0x1dcfc250>,
#  <matplotlib.lines.Line2D at 0x1dcfc410>,
#  <matplotlib.lines.Line2D at 0x1dcfc5d0>,
#  <matplotlib.lines.Line2D at 0x1dcfc790>,
#  <matplotlib.lines.Line2D at 0x1dcfc950>,
#  <matplotlib.lines.Line2D at 0x1dcfded0>,
#  <matplotlib.lines.Line2D at 0x1dcfccd0>,
#  <matplotlib.lines.Line2D at 0x1dcfce90>,
#  <matplotlib.lines.Line2D at 0x1dcf9090>,
#  <matplotlib.lines.Line2D at 0x1dcf9250>,
#  <matplotlib.lines.Line2D at 0x1dcf9410>,
#  <matplotlib.lines.Line2D at 0x1dcf95d0>,
#  <matplotlib.lines.Line2D at 0x1dcfcb50>,
#  <matplotlib.lines.Line2D at 0x1dcf9950>,
#  <matplotlib.lines.Line2D at 0x1dcf9b10>,
#  <matplotlib.lines.Line2D at 0x1dcf9cd0>,
#  <matplotlib.lines.Line2D at 0x1dcf9e90>,
#  <matplotlib.lines.Line2D at 0x1dce3090>,
#  <matplotlib.lines.Line2D at 0x1dce3250>,
#  <matplotlib.lines.Line2D at 0x1dcf97d0>,
#  <matplotlib.lines.Line2D at 0x1dce35d0>,
#  <matplotlib.lines.Line2D at 0x1dce3790>,
#  <matplotlib.lines.Line2D at 0x1dce3950>,
#  <matplotlib.lines.Line2D at 0x1dce3b10>,
#  <matplotlib.lines.Line2D at 0x1dce3cd0>,
#  <matplotlib.lines.Line2D at 0x1dce3e90>,
#  <matplotlib.lines.Line2D at 0x1dce3450>,
#  <matplotlib.lines.Line2D at 0x1dd0a250>,
#  <matplotlib.lines.Line2D at 0x1dd0a410>,
#  <matplotlib.lines.Line2D at 0x1dd0a5d0>,
#  <matplotlib.lines.Line2D at 0x1dd0a790>,
#  <matplotlib.lines.Line2D at 0x1dd0a950>,
#  <matplotlib.lines.Line2D at 0x1dd0ab10>,
#  <matplotlib.lines.Line2D at 0x1dd0acd0>,
#  <matplotlib.lines.Line2D at 0x1dd0ae90>,
#  <matplotlib.lines.Line2D at 0x282f1090>,
#  <matplotlib.lines.Line2D at 0x282f1250>,
#  <matplotlib.lines.Line2D at 0x282f1410>,
#  <matplotlib.lines.Line2D at 0x282f15d0>,
#  <matplotlib.lines.Line2D at 0x282f1790>,
#  <matplotlib.lines.Line2D at 0x1dd0ad10>,
#  <matplotlib.lines.Line2D at 0x282f1b10>,
#  <matplotlib.lines.Line2D at 0x282f1cd0>,
#  <matplotlib.lines.Line2D at 0x282f1e90>,
#  <matplotlib.lines.Line2D at 0x28300090>,
#  <matplotlib.lines.Line2D at 0x28300250>,
#  <matplotlib.lines.Line2D at 0x28300410>,
#  <matplotlib.lines.Line2D at 0x282f1990>,
#  <matplotlib.lines.Line2D at 0x28300790>,
#  <matplotlib.lines.Line2D at 0x28300950>,
#  <matplotlib.lines.Line2D at 0x28300b10>,
#  <matplotlib.lines.Line2D at 0x28300cd0>,
#  <matplotlib.lines.Line2D at 0x28300e90>,
#  <matplotlib.lines.Line2D at 0x2830a090>,
#  <matplotlib.lines.Line2D at 0x28300610>,
#  <matplotlib.lines.Line2D at 0x2830a410>,
#  <matplotlib.lines.Line2D at 0x2830a5d0>,
#  <matplotlib.lines.Line2D at 0x2830a790>,
#  <matplotlib.lines.Line2D at 0x2830a950>,
#  <matplotlib.lines.Line2D at 0x2830ab10>,
#  <matplotlib.lines.Line2D at 0x2830acd0>,
#  <matplotlib.lines.Line2D at 0x2830ae90>,
#  <matplotlib.lines.Line2D at 0x282e3090>,
#  <matplotlib.lines.Line2D at 0x282e3250>,
#  <matplotlib.lines.Line2D at 0x282e3410>,
#  <matplotlib.lines.Line2D at 0x282e35d0>,
#  <matplotlib.lines.Line2D at 0x282e3790>,
#  <matplotlib.lines.Line2D at 0x282e3950>,
#  <matplotlib.lines.Line2D at 0x2830aed0>,
#  <matplotlib.lines.Line2D at 0x282e3cd0>,
#  <matplotlib.lines.Line2D at 0x282e3e90>,
#  <matplotlib.lines.Line2D at 0x28302090>,
#  <matplotlib.lines.Line2D at 0x28302250>,
#  <matplotlib.lines.Line2D at 0x28302410>,
#  <matplotlib.lines.Line2D at 0x283025d0>,
#  <matplotlib.lines.Line2D at 0x282e3b50>,
#  <matplotlib.lines.Line2D at 0x28302950>,
#  <matplotlib.lines.Line2D at 0x28302b10>,
#  <matplotlib.lines.Line2D at 0x28302cd0>,
#  <matplotlib.lines.Line2D at 0x28302e90>,
#  <matplotlib.lines.Line2D at 0x282ea090>,
#  <matplotlib.lines.Line2D at 0x282ea250>,
#  <matplotlib.lines.Line2D at 0x283027d0>,
#  <matplotlib.lines.Line2D at 0x282ea5d0>,
#  <matplotlib.lines.Line2D at 0x282ea790>,
#  <matplotlib.lines.Line2D at 0x282ea950>,
#  <matplotlib.lines.Line2D at 0x282eab10>,
#  <matplotlib.lines.Line2D at 0x282eacd0>,
#  <matplotlib.lines.Line2D at 0x282eae90>,
#  <matplotlib.lines.Line2D at 0x282ea450>,
#  <matplotlib.lines.Line2D at 0x2830e250>,
#  <matplotlib.lines.Line2D at 0x2830e410>,
#  <matplotlib.lines.Line2D at 0x2830e5d0>,
#  <matplotlib.lines.Line2D at 0x2830e790>,
#  <matplotlib.lines.Line2D at 0x2830e950>,
#  <matplotlib.lines.Line2D at 0x2830eb10>,
#  <matplotlib.lines.Line2D at 0x2830ecd0>,
#  <matplotlib.lines.Line2D at 0x2830ee90>,
#  <matplotlib.lines.Line2D at 0x282fb090>,
#  <matplotlib.lines.Line2D at 0x282fb250>,
#  <matplotlib.lines.Line2D at 0x282fb410>,
#  <matplotlib.lines.Line2D at 0x282fb5d0>,
#  <matplotlib.lines.Line2D at 0x282fb790>,
#  <matplotlib.lines.Line2D at 0x2830ed10>,
#  <matplotlib.lines.Line2D at 0x282fbb10>,
#  <matplotlib.lines.Line2D at 0x282fbcd0>,
#  <matplotlib.lines.Line2D at 0x282fbe90>,
#  <matplotlib.lines.Line2D at 0x282ee090>,
#  <matplotlib.lines.Line2D at 0x282ee250>,
#  <matplotlib.lines.Line2D at 0x282ee410>,
#  <matplotlib.lines.Line2D at 0x282fb990>,
#  <matplotlib.lines.Line2D at 0x282ee790>,
#  <matplotlib.lines.Line2D at 0x282ee950>,
#  <matplotlib.lines.Line2D at 0x282eeb10>,
#  <matplotlib.lines.Line2D at 0x282eecd0>,
#  <matplotlib.lines.Line2D at 0x282eee90>,
#  <matplotlib.lines.Line2D at 0x28311090>,
#  <matplotlib.lines.Line2D at 0x282ee610>,
#  <matplotlib.lines.Line2D at 0x28311410>,
#  <matplotlib.lines.Line2D at 0x283115d0>,
#  <matplotlib.lines.Line2D at 0x28311790>,
#  <matplotlib.lines.Line2D at 0x28311950>,
#  <matplotlib.lines.Line2D at 0x28311b10>,
#  <matplotlib.lines.Line2D at 0x28311cd0>,
#  <matplotlib.lines.Line2D at 0x28311e90>,
#  <matplotlib.lines.Line2D at 0x282f3090>,
#  <matplotlib.lines.Line2D at 0x282f3250>,
#  <matplotlib.lines.Line2D at 0x282f3410>,
#  <matplotlib.lines.Line2D at 0x282f35d0>,
#  <matplotlib.lines.Line2D at 0x282f3790>,
#  <matplotlib.lines.Line2D at 0x282f3950>,
#  <matplotlib.lines.Line2D at 0x28311ed0>,
#  <matplotlib.lines.Line2D at 0x282f3cd0>,
#  <matplotlib.lines.Line2D at 0x282f3e90>,
#  <matplotlib.lines.Line2D at 0x282fd090>,
#  <matplotlib.lines.Line2D at 0x282fd250>,
#  <matplotlib.lines.Line2D at 0x282fd410>,
#  <matplotlib.lines.Line2D at 0x282fd5d0>,
#  <matplotlib.lines.Line2D at 0x282f3b50>,
#  <matplotlib.lines.Line2D at 0x282fd950>,
#  <matplotlib.lines.Line2D at 0x282fdb10>,
#  <matplotlib.lines.Line2D at 0x282fdcd0>,
#  <matplotlib.lines.Line2D at 0x282fde90>,
#  <matplotlib.lines.Line2D at 0x282fa090>,
#  <matplotlib.lines.Line2D at 0x282fa250>,
#  <matplotlib.lines.Line2D at 0x282fd7d0>,
#  <matplotlib.lines.Line2D at 0x282fa5d0>,
#  <matplotlib.lines.Line2D at 0x282fa790>,
#  <matplotlib.lines.Line2D at 0x282fa950>,
#  <matplotlib.lines.Line2D at 0x282fab10>,
#  <matplotlib.lines.Line2D at 0x282facd0>,
#  <matplotlib.lines.Line2D at 0x282fae90>,
#  <matplotlib.lines.Line2D at 0x282fa450>,
#  <matplotlib.lines.Line2D at 0x28318250>,
#  <matplotlib.lines.Line2D at 0x28318410>,
#  <matplotlib.lines.Line2D at 0x283185d0>,
#  <matplotlib.lines.Line2D at 0x28318790>,
#  <matplotlib.lines.Line2D at 0x28318950>,
#  <matplotlib.lines.Line2D at 0x28318b10>,
#  <matplotlib.lines.Line2D at 0x28318cd0>,
#  <matplotlib.lines.Line2D at 0x28318e90>,
#  <matplotlib.lines.Line2D at 0x28304090>,
#  <matplotlib.lines.Line2D at 0x28304250>,
#  <matplotlib.lines.Line2D at 0x28304410>,
#  <matplotlib.lines.Line2D at 0x283045d0>,
#  <matplotlib.lines.Line2D at 0x28304790>,
#  <matplotlib.lines.Line2D at 0x28318d10>,
#  <matplotlib.lines.Line2D at 0x28304b10>,
#  <matplotlib.lines.Line2D at 0x28304cd0>,
#  <matplotlib.lines.Line2D at 0x28304e90>,
#  <matplotlib.lines.Line2D at 0x2830f090>,
#  <matplotlib.lines.Line2D at 0x2830f250>,
#  <matplotlib.lines.Line2D at 0x2830f410>,
#  <matplotlib.lines.Line2D at 0x28304990>,
#  <matplotlib.lines.Line2D at 0x2830f790>,
#  <matplotlib.lines.Line2D at 0x2830f950>,
#  <matplotlib.lines.Line2D at 0x2830fb10>,
#  <matplotlib.lines.Line2D at 0x2830fcd0>,
#  <matplotlib.lines.Line2D at 0x2830fe90>,
#  <matplotlib.lines.Line2D at 0x28307090>,
#  <matplotlib.lines.Line2D at 0x2830f610>,
#  <matplotlib.lines.Line2D at 0x28307410>,
#  <matplotlib.lines.Line2D at 0x283075d0>,
#  <matplotlib.lines.Line2D at 0x28307790>,
#  <matplotlib.lines.Line2D at 0x28307950>,
#  <matplotlib.lines.Line2D at 0x28307b10>,
#  <matplotlib.lines.Line2D at 0x28307cd0>,
#  <matplotlib.lines.Line2D at 0x28307e90>,
#  <matplotlib.lines.Line2D at 0x282f0090>,
#  <matplotlib.lines.Line2D at 0x282f0250>,
#  <matplotlib.lines.Line2D at 0x282f0410>,
#  <matplotlib.lines.Line2D at 0x282f05d0>,
#  <matplotlib.lines.Line2D at 0x282f0790>,
#  <matplotlib.lines.Line2D at 0x282f0950>,
#  <matplotlib.lines.Line2D at 0x28307ed0>,
#  <matplotlib.lines.Line2D at 0x282f0cd0>,
#  <matplotlib.lines.Line2D at 0x282f0e90>,
#  <matplotlib.lines.Line2D at 0x282eb090>,
#  <matplotlib.lines.Line2D at 0x282eb250>,
#  <matplotlib.lines.Line2D at 0x282eb410>,
#  <matplotlib.lines.Line2D at 0x282eb5d0>,
#  <matplotlib.lines.Line2D at 0x282f0b50>,
#  <matplotlib.lines.Line2D at 0x282eb950>,
#  <matplotlib.lines.Line2D at 0x282ebb10>,
#  <matplotlib.lines.Line2D at 0x282ebcd0>,
#  <matplotlib.lines.Line2D at 0x282ebe90>,
#  <matplotlib.lines.Line2D at 0x28309090>,
#  <matplotlib.lines.Line2D at 0x28309250>,
#  <matplotlib.lines.Line2D at 0x282eb7d0>,
#  <matplotlib.lines.Line2D at 0x283095d0>,
#  <matplotlib.lines.Line2D at 0x28309790>,
#  <matplotlib.lines.Line2D at 0x28309950>,
#  <matplotlib.lines.Line2D at 0x28309b10>,
#  <matplotlib.lines.Line2D at 0x28309cd0>,
#  <matplotlib.lines.Line2D at 0x28309e90>,
#  <matplotlib.lines.Line2D at 0x28309450>,
#  <matplotlib.lines.Line2D at 0x282df250>,
#  <matplotlib.lines.Line2D at 0x282df410>,
#  <matplotlib.lines.Line2D at 0x282df5d0>,
#  <matplotlib.lines.Line2D at 0x282df790>,
#  <matplotlib.lines.Line2D at 0x282df950>,
#  <matplotlib.lines.Line2D at 0x282dfb10>,
#  <matplotlib.lines.Line2D at 0x282dfcd0>,
#  <matplotlib.lines.Line2D at 0x282dfe90>,
#  <matplotlib.lines.Line2D at 0x282f7090>,
#  <matplotlib.lines.Line2D at 0x282f7250>,
#  <matplotlib.lines.Line2D at 0x282f7410>,
#  <matplotlib.lines.Line2D at 0x282f75d0>,
#  <matplotlib.lines.Line2D at 0x282f7790>,
#  <matplotlib.lines.Line2D at 0x282dfd10>,
#  <matplotlib.lines.Line2D at 0x282f7b10>,
#  <matplotlib.lines.Line2D at 0x282f7cd0>,
#  <matplotlib.lines.Line2D at 0x282f7e90>,
#  <matplotlib.lines.Line2D at 0x28314090>,
#  <matplotlib.lines.Line2D at 0x28314250>,
#  <matplotlib.lines.Line2D at 0x28314410>,
#  <matplotlib.lines.Line2D at 0x282f7990>,
#  <matplotlib.lines.Line2D at 0x28314790>,
#  <matplotlib.lines.Line2D at 0x28314950>,
#  <matplotlib.lines.Line2D at 0x28314b10>,
#  <matplotlib.lines.Line2D at 0x28314cd0>,
#  <matplotlib.lines.Line2D at 0x28314e90>,
#  <matplotlib.lines.Line2D at 0x2847c090>,
#  <matplotlib.lines.Line2D at 0x28314610>,
#  <matplotlib.lines.Line2D at 0x2847c410>,
#  <matplotlib.lines.Line2D at 0x2847c5d0>,
#  <matplotlib.lines.Line2D at 0x2847c790>,
#  <matplotlib.lines.Line2D at 0x2847c950>,
#  <matplotlib.lines.Line2D at 0x2847cb10>,
#  <matplotlib.lines.Line2D at 0x2847ccd0>,
#  <matplotlib.lines.Line2D at 0x2847ce90>,
#  <matplotlib.lines.Line2D at 0x2849e090>,
#  <matplotlib.lines.Line2D at 0x2849e250>,
#  <matplotlib.lines.Line2D at 0x2849e410>,
#  <matplotlib.lines.Line2D at 0x2849e5d0>,
#  <matplotlib.lines.Line2D at 0x2849e790>,
#  <matplotlib.lines.Line2D at 0x2849e950>,
#  <matplotlib.lines.Line2D at 0x2847ced0>,
#  <matplotlib.lines.Line2D at 0x2849ecd0>,
#  <matplotlib.lines.Line2D at 0x2849ee90>,
#  <matplotlib.lines.Line2D at 0x28468090>,
#  <matplotlib.lines.Line2D at 0x28468250>,
#  <matplotlib.lines.Line2D at 0x28468410>,
#  <matplotlib.lines.Line2D at 0x284685d0>,
#  <matplotlib.lines.Line2D at 0x2849eb50>,
#  <matplotlib.lines.Line2D at 0x28468950>,
#  <matplotlib.lines.Line2D at 0x28468b10>,
#  <matplotlib.lines.Line2D at 0x28468cd0>,
#  <matplotlib.lines.Line2D at 0x28468e90>,
#  <matplotlib.lines.Line2D at 0x2847f090>,
#  <matplotlib.lines.Line2D at 0x2847f250>,
#  <matplotlib.lines.Line2D at 0x284687d0>,
#  <matplotlib.lines.Line2D at 0x2847f5d0>,
#  <matplotlib.lines.Line2D at 0x2847f790>,
#  <matplotlib.lines.Line2D at 0x2847f950>,
#  <matplotlib.lines.Line2D at 0x2847fb10>,
#  <matplotlib.lines.Line2D at 0x2847fcd0>,
#  <matplotlib.lines.Line2D at 0x2847fe90>,
#  <matplotlib.lines.Line2D at 0x2847f450>,
#  <matplotlib.lines.Line2D at 0x28489250>,
#  <matplotlib.lines.Line2D at 0x28489410>,
#  <matplotlib.lines.Line2D at 0x284895d0>,
#  <matplotlib.lines.Line2D at 0x28489790>,
#  <matplotlib.lines.Line2D at 0x28489950>,
#  <matplotlib.lines.Line2D at 0x28489b10>,
#  <matplotlib.lines.Line2D at 0x28489cd0>,
#  <matplotlib.lines.Line2D at 0x28489e90>,
#  <matplotlib.lines.Line2D at 0x28493090>,
#  <matplotlib.lines.Line2D at 0x28493250>,
#  <matplotlib.lines.Line2D at 0x28493410>,
#  <matplotlib.lines.Line2D at 0x284935d0>,
#  <matplotlib.lines.Line2D at 0x28493790>,
#  <matplotlib.lines.Line2D at 0x28489d10>,
#  <matplotlib.lines.Line2D at 0x28493b10>,
#  <matplotlib.lines.Line2D at 0x28493cd0>,
#  <matplotlib.lines.Line2D at 0x28493e90>,
#  <matplotlib.lines.Line2D at 0x28477090>,
#  <matplotlib.lines.Line2D at 0x28477250>,
#  <matplotlib.lines.Line2D at 0x28477410>,
#  <matplotlib.lines.Line2D at 0x28493990>,
#  <matplotlib.lines.Line2D at 0x28477790>,
#  <matplotlib.lines.Line2D at 0x28477950>,
#  <matplotlib.lines.Line2D at 0x28477b10>,
#  <matplotlib.lines.Line2D at 0x28477cd0>,
#  <matplotlib.lines.Line2D at 0x28477e90>,
#  <matplotlib.lines.Line2D at 0x284a1090>,
#  <matplotlib.lines.Line2D at 0x28477610>,
#  <matplotlib.lines.Line2D at 0x284a1410>,
#  <matplotlib.lines.Line2D at 0x284a15d0>,
#  <matplotlib.lines.Line2D at 0x284a1790>,
#  <matplotlib.lines.Line2D at 0x284a1950>,
#  <matplotlib.lines.Line2D at 0x284a1b10>,
#  <matplotlib.lines.Line2D at 0x284a1cd0>,
#  <matplotlib.lines.Line2D at 0x284a1e90>,
#  <matplotlib.lines.Line2D at 0x28480090>,
#  <matplotlib.lines.Line2D at 0x28480250>,
#  <matplotlib.lines.Line2D at 0x28480410>,
#  <matplotlib.lines.Line2D at 0x284805d0>,
#  <matplotlib.lines.Line2D at 0x28480790>,
#  <matplotlib.lines.Line2D at 0x28480950>,
#  <matplotlib.lines.Line2D at 0x284a1ed0>,
#  <matplotlib.lines.Line2D at 0x28480cd0>,
#  <matplotlib.lines.Line2D at 0x28480e90>,
#  <matplotlib.lines.Line2D at 0x2846b090>,
#  <matplotlib.lines.Line2D at 0x2846b250>,
#  <matplotlib.lines.Line2D at 0x2846b410>,
#  <matplotlib.lines.Line2D at 0x2846b5d0>,
#  <matplotlib.lines.Line2D at 0x28480b50>,
#  <matplotlib.lines.Line2D at 0x2846b950>,
#  <matplotlib.lines.Line2D at 0x2846bb10>,
#  <matplotlib.lines.Line2D at 0x2846bcd0>,
#  <matplotlib.lines.Line2D at 0x2846be90>,
#  <matplotlib.lines.Line2D at 0x2849d090>,
#  <matplotlib.lines.Line2D at 0x2849d250>,
#  <matplotlib.lines.Line2D at 0x2846b7d0>,
#  <matplotlib.lines.Line2D at 0x2849d5d0>,
#  <matplotlib.lines.Line2D at 0x2849d790>,
#  <matplotlib.lines.Line2D at 0x2849d950>,
#  <matplotlib.lines.Line2D at 0x2849db10>,
#  <matplotlib.lines.Line2D at 0x2849dcd0>,
#  <matplotlib.lines.Line2D at 0x2849de90>,
#  <matplotlib.lines.Line2D at 0x2849d450>,
#  <matplotlib.lines.Line2D at 0x2846c250>,
#  <matplotlib.lines.Line2D at 0x2846c410>,
#  <matplotlib.lines.Line2D at 0x2846c5d0>,
#  <matplotlib.lines.Line2D at 0x2846c790>,
#  <matplotlib.lines.Line2D at 0x2846c950>,
#  <matplotlib.lines.Line2D at 0x2846cb10>,
#  <matplotlib.lines.Line2D at 0x2846ccd0>,
#  <matplotlib.lines.Line2D at 0x2846ce90>,
#  <matplotlib.lines.Line2D at 0x284a0090>,
#  <matplotlib.lines.Line2D at 0x284a0250>,
#  <matplotlib.lines.Line2D at 0x284a0410>,
#  <matplotlib.lines.Line2D at 0x284a05d0>,
#  <matplotlib.lines.Line2D at 0x284a0790>,
#  <matplotlib.lines.Line2D at 0x2846cd10>,
#  <matplotlib.lines.Line2D at 0x284a0b10>,
#  <matplotlib.lines.Line2D at 0x284a0cd0>,
#  <matplotlib.lines.Line2D at 0x284a0e90>,
#  <matplotlib.lines.Line2D at 0x2847b090>,
#  <matplotlib.lines.Line2D at 0x2847b250>,
#  <matplotlib.lines.Line2D at 0x2847b410>,
#  <matplotlib.lines.Line2D at 0x284a0990>,
#  <matplotlib.lines.Line2D at 0x2847b790>,
#  <matplotlib.lines.Line2D at 0x2847b950>,
#  <matplotlib.lines.Line2D at 0x2847bb10>,
#  <matplotlib.lines.Line2D at 0x2847bcd0>,
#  <matplotlib.lines.Line2D at 0x2847be90>,
#  <matplotlib.lines.Line2D at 0x28475090>,
#  <matplotlib.lines.Line2D at 0x2847b610>,
#  <matplotlib.lines.Line2D at 0x28475410>,
#  <matplotlib.lines.Line2D at 0x284755d0>,
#  <matplotlib.lines.Line2D at 0x28475790>,
#  <matplotlib.lines.Line2D at 0x28475950>,
#  <matplotlib.lines.Line2D at 0x28475b10>,
#  <matplotlib.lines.Line2D at 0x28475cd0>,
#  <matplotlib.lines.Line2D at 0x28475e90>,
#  <matplotlib.lines.Line2D at 0x28476090>,
#  <matplotlib.lines.Line2D at 0x28476250>,
#  <matplotlib.lines.Line2D at 0x28476410>,
#  <matplotlib.lines.Line2D at 0x284765d0>,
#  <matplotlib.lines.Line2D at 0x28476790>,
#  <matplotlib.lines.Line2D at 0x28476950>,
#  <matplotlib.lines.Line2D at 0x28475ed0>,
#  <matplotlib.lines.Line2D at 0x28476cd0>,
#  <matplotlib.lines.Line2D at 0x28476e90>,
#  <matplotlib.lines.Line2D at 0x28494090>,
#  <matplotlib.lines.Line2D at 0x28494250>,
#  <matplotlib.lines.Line2D at 0x28494410>,
#  <matplotlib.lines.Line2D at 0x284945d0>,
#  <matplotlib.lines.Line2D at 0x28476b50>,
#  <matplotlib.lines.Line2D at 0x28494950>,
#  <matplotlib.lines.Line2D at 0x28494b10>,
#  <matplotlib.lines.Line2D at 0x28494cd0>,
#  <matplotlib.lines.Line2D at 0x28494e90>,
#  <matplotlib.lines.Line2D at 0x2848e090>,
#  <matplotlib.lines.Line2D at 0x2848e250>,
#  <matplotlib.lines.Line2D at 0x284947d0>,
#  <matplotlib.lines.Line2D at 0x2848e5d0>,
#  <matplotlib.lines.Line2D at 0x2848e790>,
#  <matplotlib.lines.Line2D at 0x2848e950>,
#  <matplotlib.lines.Line2D at 0x2848eb10>,
#  <matplotlib.lines.Line2D at 0x2848ecd0>,
#  <matplotlib.lines.Line2D at 0x2848ee90>,
#  <matplotlib.lines.Line2D at 0x2848e450>,
#  <matplotlib.lines.Line2D at 0x28474250>,
#  <matplotlib.lines.Line2D at 0x28474410>,
#  <matplotlib.lines.Line2D at 0x284745d0>,
#  <matplotlib.lines.Line2D at 0x28474790>,
#  <matplotlib.lines.Line2D at 0x28474950>,
#  <matplotlib.lines.Line2D at 0x28474b10>,
#  <matplotlib.lines.Line2D at 0x28474cd0>,
#  <matplotlib.lines.Line2D at 0x28474e90>,
#  <matplotlib.lines.Line2D at 0x28492090>,
#  <matplotlib.lines.Line2D at 0x28492250>,
#  <matplotlib.lines.Line2D at 0x28492410>,
#  <matplotlib.lines.Line2D at 0x284925d0>,
#  <matplotlib.lines.Line2D at 0x28492790>,
#  <matplotlib.lines.Line2D at 0x28474d10>,
#  <matplotlib.lines.Line2D at 0x28492b10>,
#  <matplotlib.lines.Line2D at 0x28492cd0>,
#  <matplotlib.lines.Line2D at 0x28492e90>,
#  <matplotlib.lines.Line2D at 0x2846a090>,
#  <matplotlib.lines.Line2D at 0x2846a250>,
#  <matplotlib.lines.Line2D at 0x2846a410>,
#  <matplotlib.lines.Line2D at 0x28492990>,
#  <matplotlib.lines.Line2D at 0x2846a790>,
#  <matplotlib.lines.Line2D at 0x2846a950>,
#  <matplotlib.lines.Line2D at 0x2846ab10>,
#  <matplotlib.lines.Line2D at 0x2846acd0>,
#  <matplotlib.lines.Line2D at 0x2846ae90>,
#  <matplotlib.lines.Line2D at 0x2849b090>,
#  <matplotlib.lines.Line2D at 0x2846a610>,
#  <matplotlib.lines.Line2D at 0x2849b410>,
#  <matplotlib.lines.Line2D at 0x2849b5d0>,
#  <matplotlib.lines.Line2D at 0x2849b790>,
#  <matplotlib.lines.Line2D at 0x2849b950>,
#  <matplotlib.lines.Line2D at 0x2849bb10>,
#  <matplotlib.lines.Line2D at 0x2849bcd0>,
#  <matplotlib.lines.Line2D at 0x2849be90>,
#  <matplotlib.lines.Line2D at 0x28482090>,
#  <matplotlib.lines.Line2D at 0x28482250>,
#  <matplotlib.lines.Line2D at 0x28482410>,
#  <matplotlib.lines.Line2D at 0x284825d0>,
#  <matplotlib.lines.Line2D at 0x28482790>,
#  <matplotlib.lines.Line2D at 0x28482950>,
#  <matplotlib.lines.Line2D at 0x2849bed0>,
#  <matplotlib.lines.Line2D at 0x28482cd0>,
#  <matplotlib.lines.Line2D at 0x28482e90>,
#  <matplotlib.lines.Line2D at 0x28467090>,
#  <matplotlib.lines.Line2D at 0x28467250>,
#  <matplotlib.lines.Line2D at 0x28467410>,
#  <matplotlib.lines.Line2D at 0x284675d0>,
#  <matplotlib.lines.Line2D at 0x28482b50>,
#  <matplotlib.lines.Line2D at 0x28467950>,
#  <matplotlib.lines.Line2D at 0x28467b10>,
#  <matplotlib.lines.Line2D at 0x28467cd0>,
#  <matplotlib.lines.Line2D at 0x28467e90>,
#  <matplotlib.lines.Line2D at 0x1bcf0090>,
#  <matplotlib.lines.Line2D at 0x1bcf0250>,
#  <matplotlib.lines.Line2D at 0x284677d0>,
#  <matplotlib.lines.Line2D at 0x1bcf05d0>,
#  <matplotlib.lines.Line2D at 0x1bcf0790>,
#  <matplotlib.lines.Line2D at 0x1bcf0950>,
#  <matplotlib.lines.Line2D at 0x1bcf0b10>,
#  <matplotlib.lines.Line2D at 0x1bcf0cd0>,
#  <matplotlib.lines.Line2D at 0x1bcf0e90>,
#  <matplotlib.lines.Line2D at 0x1bcf0450>,
#  <matplotlib.lines.Line2D at 0x1bcbf250>,
#  <matplotlib.lines.Line2D at 0x1bcbf410>,
#  <matplotlib.lines.Line2D at 0x1bcbf5d0>,
#  <matplotlib.lines.Line2D at 0x1bcbf790>,
#  <matplotlib.lines.Line2D at 0x1bcbf950>,
#  <matplotlib.lines.Line2D at 0x1bcbfb10>,
#  <matplotlib.lines.Line2D at 0x1bcbfcd0>,
#  <matplotlib.lines.Line2D at 0x1bcbfe90>,
#  <matplotlib.lines.Line2D at 0x1bcf1090>,
#  <matplotlib.lines.Line2D at 0x1bcf1250>,
#  <matplotlib.lines.Line2D at 0x1bcf1410>,
#  <matplotlib.lines.Line2D at 0x1bcf15d0>,
#  <matplotlib.lines.Line2D at 0x1bcf1790>,
#  <matplotlib.lines.Line2D at 0x1bcbfd10>,
#  <matplotlib.lines.Line2D at 0x1bcf1b10>,
#  <matplotlib.lines.Line2D at 0x1bcf1cd0>,
#  <matplotlib.lines.Line2D at 0x1bcf1e90>,
#  <matplotlib.lines.Line2D at 0x1bcba090>,
#  <matplotlib.lines.Line2D at 0x1bcba250>,
#  <matplotlib.lines.Line2D at 0x1bcba410>,
#  <matplotlib.lines.Line2D at 0x1bcf1990>,
#  <matplotlib.lines.Line2D at 0x1bcba790>,
#  <matplotlib.lines.Line2D at 0x1bcba950>,
#  <matplotlib.lines.Line2D at 0x1bcbab10>,
#  <matplotlib.lines.Line2D at 0x1bcbacd0>,
#  <matplotlib.lines.Line2D at 0x1bcbae90>,
#  <matplotlib.lines.Line2D at 0x1bced090>,
#  <matplotlib.lines.Line2D at 0x1bcba610>,
#  <matplotlib.lines.Line2D at 0x1bced410>,
#  <matplotlib.lines.Line2D at 0x1bced5d0>,
#  <matplotlib.lines.Line2D at 0x1bced790>,
#  <matplotlib.lines.Line2D at 0x1bced950>,
#  <matplotlib.lines.Line2D at 0x1bcedb10>,
#  <matplotlib.lines.Line2D at 0x1bcedcd0>,
#  <matplotlib.lines.Line2D at 0x1bcede90>,
#  <matplotlib.lines.Line2D at 0x1bcc5090>,
#  <matplotlib.lines.Line2D at 0x1bcc5250>,
#  <matplotlib.lines.Line2D at 0x1bcc5410>,
#  <matplotlib.lines.Line2D at 0x1bcc55d0>,
#  <matplotlib.lines.Line2D at 0x1bcc5790>,
#  <matplotlib.lines.Line2D at 0x1bcc5950>,
#  <matplotlib.lines.Line2D at 0x1bceded0>,
#  <matplotlib.lines.Line2D at 0x1bcc5cd0>,
#  <matplotlib.lines.Line2D at 0x1bcc5e90>,
#  <matplotlib.lines.Line2D at 0x1bcf2090>,
#  <matplotlib.lines.Line2D at 0x1bcf2250>,
#  <matplotlib.lines.Line2D at 0x1bcf2410>,
#  <matplotlib.lines.Line2D at 0x1bcf25d0>,
#  <matplotlib.lines.Line2D at 0x1bcc5b50>,
#  <matplotlib.lines.Line2D at 0x1bcf2950>,
#  <matplotlib.lines.Line2D at 0x1bcf2b10>,
#  <matplotlib.lines.Line2D at 0x1bcf2cd0>,
#  <matplotlib.lines.Line2D at 0x1bcf2e90>,
#  <matplotlib.lines.Line2D at 0x1bcc1090>,
#  <matplotlib.lines.Line2D at 0x1bcc1250>,
#  <matplotlib.lines.Line2D at 0x1bcf27d0>,
#  <matplotlib.lines.Line2D at 0x1bcc15d0>,
#  <matplotlib.lines.Line2D at 0x1bcc1790>,
#  <matplotlib.lines.Line2D at 0x1bcc1950>,
#  <matplotlib.lines.Line2D at 0x1bcc1b10>,
#  <matplotlib.lines.Line2D at 0x1bcc1cd0>,
#  <matplotlib.lines.Line2D at 0x1bcc1e90>,
#  <matplotlib.lines.Line2D at 0x1bcc1450>,
#  <matplotlib.lines.Line2D at 0x1bcc4250>,
#  <matplotlib.lines.Line2D at 0x1bcc4410>,
#  <matplotlib.lines.Line2D at 0x1bcc45d0>,
#  <matplotlib.lines.Line2D at 0x1bcc4790>,
#  <matplotlib.lines.Line2D at 0x1bcc4950>,
#  <matplotlib.lines.Line2D at 0x1bcc4b10>,
#  <matplotlib.lines.Line2D at 0x1bcc4cd0>,
#  <matplotlib.lines.Line2D at 0x1bcc4e90>,
#  <matplotlib.lines.Line2D at 0x1bce5090>,
#  <matplotlib.lines.Line2D at 0x1bce5250>,
#  <matplotlib.lines.Line2D at 0x1bce5410>,
#  <matplotlib.lines.Line2D at 0x1bce55d0>,
#  <matplotlib.lines.Line2D at 0x1bce5790>,
#  <matplotlib.lines.Line2D at 0x1bcc4d10>,
#  <matplotlib.lines.Line2D at 0x1bce5b10>,
#  <matplotlib.lines.Line2D at 0x1bce5cd0>,
#  <matplotlib.lines.Line2D at 0x1bce5e90>,
#  <matplotlib.lines.Line2D at 0x1bcc7090>,
#  <matplotlib.lines.Line2D at 0x1bcc7250>,
#  <matplotlib.lines.Line2D at 0x1bcc7410>,
#  <matplotlib.lines.Line2D at 0x1bce5990>,
# ...
#  <matplotlib.lines.Line2D at 0x1a0ead10>,
#  <matplotlib.lines.Line2D at 0x1a0eab90>,
#  <matplotlib.lines.Line2D at 0x1a0ea310>,
#  <matplotlib.lines.Line2D at 0x1a0ea410>,
#  <matplotlib.lines.Line2D at 0x1a0ea790>,
#  <matplotlib.lines.Line2D at 0x1a0ea110>,
#  <matplotlib.lines.Line2D at 0x1a0eaf10>,
#  <matplotlib.lines.Line2D at 0x1a0f7550>,
#  <matplotlib.lines.Line2D at 0x1a0f7610>,
#  <matplotlib.lines.Line2D at 0x1a0f71d0>,
#  <matplotlib.lines.Line2D at 0x1a0f7290>,
#  <matplotlib.lines.Line2D at 0x1a0f7e10>,
#  <matplotlib.lines.Line2D at 0x1a0f7f50>,
#  <matplotlib.lines.Line2D at 0x1a0f79d0>,
#  <matplotlib.lines.Line2D at 0x1a0f7ad0>,
#  <matplotlib.lines.Line2D at 0x1a0d5090>,
#  <matplotlib.lines.Line2D at 0x1a0d5250>,
#  <matplotlib.lines.Line2D at 0x1a0d5410>,
#  <matplotlib.lines.Line2D at 0x1a0d55d0>,
#  <matplotlib.lines.Line2D at 0x1a0d5790>,
#  <matplotlib.lines.Line2D at 0x1a0f7a50>,
#  <matplotlib.lines.Line2D at 0x1a0d5b10>,
#  <matplotlib.lines.Line2D at 0x1a0d5cd0>,
#  <matplotlib.lines.Line2D at 0x1a0d5e90>,
#  <matplotlib.lines.Line2D at 0x1a0df090>,
#  <matplotlib.lines.Line2D at 0x1a0df250>,
#  <matplotlib.lines.Line2D at 0x1a0df410>,
#  <matplotlib.lines.Line2D at 0x1a0d5990>,
#  <matplotlib.lines.Line2D at 0x1a0df790>,
#  <matplotlib.lines.Line2D at 0x1a0df950>,
#  <matplotlib.lines.Line2D at 0x1a0dfb10>,
#  <matplotlib.lines.Line2D at 0x1a0dfcd0>,
#  <matplotlib.lines.Line2D at 0x1a0dfe90>,
#  <matplotlib.lines.Line2D at 0x1a0d8090>,
#  <matplotlib.lines.Line2D at 0x1a0df610>,
#  <matplotlib.lines.Line2D at 0x1a0d8410>,
#  <matplotlib.lines.Line2D at 0x1a0d85d0>,
#  <matplotlib.lines.Line2D at 0x1a0d8790>,
#  <matplotlib.lines.Line2D at 0x1a0d8950>,
#  <matplotlib.lines.Line2D at 0x1a0d8b10>,
#  <matplotlib.lines.Line2D at 0x1a0d8cd0>,
#  <matplotlib.lines.Line2D at 0x1a0d8e90>,
#  <matplotlib.lines.Line2D at 0x1a0ec090>,
#  <matplotlib.lines.Line2D at 0x1a0ec250>,
#  <matplotlib.lines.Line2D at 0x1a0ec410>,
#  <matplotlib.lines.Line2D at 0x1a0ec5d0>,
#  <matplotlib.lines.Line2D at 0x1a0ec790>,
#  <matplotlib.lines.Line2D at 0x1a0ec950>,
#  <matplotlib.lines.Line2D at 0x1a0d8ed0>,
#  <matplotlib.lines.Line2D at 0x1a0eccd0>,
#  <matplotlib.lines.Line2D at 0x1a0ece90>,
#  <matplotlib.lines.Line2D at 0x1a0ef810>,
#  <matplotlib.lines.Line2D at 0x1a0ef8d0>,
#  <matplotlib.lines.Line2D at 0x1a0effd0>,
#  <matplotlib.lines.Line2D at 0x1a0efe10>,
#  <matplotlib.lines.Line2D at 0x1a0ecb50>,
#  <matplotlib.lines.Line2D at 0x1a0ef510>,
#  <matplotlib.lines.Line2D at 0x1a0ef590>,
#  <matplotlib.lines.Line2D at 0x1a0ef190>,
#  <matplotlib.lines.Line2D at 0x1a0ef210>,
#  <matplotlib.lines.Line2D at 0x1a0f0090>,
#  <matplotlib.lines.Line2D at 0x1a0f0250>,
#  <matplotlib.lines.Line2D at 0x1a0ef150>,
#  <matplotlib.lines.Line2D at 0x1a0f05d0>,
#  <matplotlib.lines.Line2D at 0x1a0f0790>,
#  <matplotlib.lines.Line2D at 0x1a0f0950>,
#  <matplotlib.lines.Line2D at 0x1a0f0b10>,
#  <matplotlib.lines.Line2D at 0x1a0f0cd0>,
#  <matplotlib.lines.Line2D at 0x1a0f0e90>,
#  <matplotlib.lines.Line2D at 0x1a0f0450>,
#  <matplotlib.lines.Line2D at 0x19c508d0>,
#  <matplotlib.lines.Line2D at 0x19c50f90>,
#  <matplotlib.lines.Line2D at 0x19c50a90>,
#  <matplotlib.lines.Line2D at 0x19c50290>,
#  <matplotlib.lines.Line2D at 0x19c50c10>,
#  <matplotlib.lines.Line2D at 0x19c50c90>,
#  <matplotlib.lines.Line2D at 0x19c507d0>,
#  <matplotlib.lines.Line2D at 0x19c50d10>,
#  <matplotlib.lines.Line2D at 0x19c72210>,
#  <matplotlib.lines.Line2D at 0x19c72950>,
#  <matplotlib.lines.Line2D at 0x19c72b90>,
#  <matplotlib.lines.Line2D at 0x19c72f90>,
#  <matplotlib.lines.Line2D at 0x19c72b10>,
#  <matplotlib.lines.Line2D at 0x19c50a50>,
#  <matplotlib.lines.Line2D at 0x19c72d50>,
#  <matplotlib.lines.Line2D at 0x19c72190>,
#  <matplotlib.lines.Line2D at 0x19c72e90>,
#  <matplotlib.lines.Line2D at 0x19c74a10>,
#  <matplotlib.lines.Line2D at 0x19c74b10>,
#  <matplotlib.lines.Line2D at 0x19c74890>,
#  <matplotlib.lines.Line2D at 0x19c729d0>,
#  <matplotlib.lines.Line2D at 0x19c74590>,
#  <matplotlib.lines.Line2D at 0x19c74e90>,
#  <matplotlib.lines.Line2D at 0x19c74390>,
#  <matplotlib.lines.Line2D at 0x19c74150>,
#  <matplotlib.lines.Line2D at 0x19c74bd0>,
#  <matplotlib.lines.Line2D at 0x19c51090>,
#  <matplotlib.lines.Line2D at 0x19c74090>,
#  <matplotlib.lines.Line2D at 0x19c51410>,
#  <matplotlib.lines.Line2D at 0x19c515d0>,
#  <matplotlib.lines.Line2D at 0x19c51790>,
#  <matplotlib.lines.Line2D at 0x19c51950>,
#  <matplotlib.lines.Line2D at 0x19c51b10>,
#  <matplotlib.lines.Line2D at 0x19c51cd0>,
#  <matplotlib.lines.Line2D at 0x19c51e90>,
#  <matplotlib.lines.Line2D at 0x19c68090>,
#  <matplotlib.lines.Line2D at 0x19c68250>,
#  <matplotlib.lines.Line2D at 0x19c68410>,
#  <matplotlib.lines.Line2D at 0x19c685d0>,
#  <matplotlib.lines.Line2D at 0x19c68790>,
#  <matplotlib.lines.Line2D at 0x19c68950>,
#  <matplotlib.lines.Line2D at 0x19c51ed0>,
#  <matplotlib.lines.Line2D at 0x19c68cd0>,
#  <matplotlib.lines.Line2D at 0x19c68e90>,
#  <matplotlib.lines.Line2D at 0x19c4f090>,
#  <matplotlib.lines.Line2D at 0x19c4f250>,
#  <matplotlib.lines.Line2D at 0x19c4f410>,
#  <matplotlib.lines.Line2D at 0x19c4f5d0>,
#  <matplotlib.lines.Line2D at 0x19c68b50>,
#  <matplotlib.lines.Line2D at 0x19c4f950>,
#  <matplotlib.lines.Line2D at 0x19c4fb10>,
#  <matplotlib.lines.Line2D at 0x19c4fcd0>,
#  <matplotlib.lines.Line2D at 0x19c4fe90>,
#  <matplotlib.lines.Line2D at 0x19c69090>,
#  <matplotlib.lines.Line2D at 0x19c69250>,
#  <matplotlib.lines.Line2D at 0x19c4f7d0>,
#  <matplotlib.lines.Line2D at 0x19c695d0>,
#  <matplotlib.lines.Line2D at 0x19c69790>,
#  <matplotlib.lines.Line2D at 0x19c69950>,
#  <matplotlib.lines.Line2D at 0x19c69b10>,
#  <matplotlib.lines.Line2D at 0x19c69cd0>,
#  <matplotlib.lines.Line2D at 0x19c69e90>,
#  <matplotlib.lines.Line2D at 0x19c69450>,
#  <matplotlib.lines.Line2D at 0x19c70250>,
#  <matplotlib.lines.Line2D at 0x19c70410>,
#  <matplotlib.lines.Line2D at 0x19c705d0>,
#  <matplotlib.lines.Line2D at 0x19c70790>,
#  <matplotlib.lines.Line2D at 0x19c70950>,
#  <matplotlib.lines.Line2D at 0x19c70b10>,
#  <matplotlib.lines.Line2D at 0x19c70cd0>,
#  <matplotlib.lines.Line2D at 0x19c70e90>,
#  <matplotlib.lines.Line2D at 0x19c83950>,
#  <matplotlib.lines.Line2D at 0x19c83990>,
#  <matplotlib.lines.Line2D at 0x19c83f90>,
#  <matplotlib.lines.Line2D at 0x19c839d0>,
#  <matplotlib.lines.Line2D at 0x19c83b10>,
#  <matplotlib.lines.Line2D at 0x19c70d10>,
#  <matplotlib.lines.Line2D at 0x19c83110>,
#  <matplotlib.lines.Line2D at 0x19c83390>,
#  <matplotlib.lines.Line2D at 0x19c83450>,
#  <matplotlib.lines.Line2D at 0x19c61090>,
#  <matplotlib.lines.Line2D at 0x19c61250>,
#  <matplotlib.lines.Line2D at 0x19c61410>,
#  <matplotlib.lines.Line2D at 0x19c83250>,
#  <matplotlib.lines.Line2D at 0x19c61790>,
#  <matplotlib.lines.Line2D at 0x19c61950>,
#  <matplotlib.lines.Line2D at 0x19c61b10>,
#  <matplotlib.lines.Line2D at 0x19c61cd0>,
#  <matplotlib.lines.Line2D at 0x19c61e90>,
#  <matplotlib.lines.Line2D at 0x19c85090>,
#  <matplotlib.lines.Line2D at 0x19c61610>,
#  <matplotlib.lines.Line2D at 0x19c85410>,
#  <matplotlib.lines.Line2D at 0x19c855d0>,
#  <matplotlib.lines.Line2D at 0x19c85790>,
#  <matplotlib.lines.Line2D at 0x19c85950>,
#  <matplotlib.lines.Line2D at 0x19c85b10>,
#  <matplotlib.lines.Line2D at 0x19c85cd0>,
#  <matplotlib.lines.Line2D at 0x19c85e90>,
#  <matplotlib.lines.Line2D at 0x19c71090>,
#  <matplotlib.lines.Line2D at 0x19c71250>,
#  <matplotlib.lines.Line2D at 0x19c71410>,
#  <matplotlib.lines.Line2D at 0x19c715d0>,
#  <matplotlib.lines.Line2D at 0x19c71790>,
#  <matplotlib.lines.Line2D at 0x19c71950>,
#  <matplotlib.lines.Line2D at 0x19c85ed0>,
#  <matplotlib.lines.Line2D at 0x19c71cd0>,
#  <matplotlib.lines.Line2D at 0x19c71e90>,
#  <matplotlib.lines.Line2D at 0x19c65090>,
#  <matplotlib.lines.Line2D at 0x19c65250>,
#  <matplotlib.lines.Line2D at 0x19c65410>,
#  <matplotlib.lines.Line2D at 0x19c655d0>,
#  <matplotlib.lines.Line2D at 0x19c71b50>,
#  <matplotlib.lines.Line2D at 0x19c65950>,
#  <matplotlib.lines.Line2D at 0x19c65b10>,
#  <matplotlib.lines.Line2D at 0x19c65cd0>,
#  <matplotlib.lines.Line2D at 0x19c65e90>,
#  <matplotlib.lines.Line2D at 0x19c6a1d0>,
#  <matplotlib.lines.Line2D at 0x19c6a3d0>,
#  <matplotlib.lines.Line2D at 0x19c657d0>,
#  <matplotlib.lines.Line2D at 0x19c6a350>,
#  <matplotlib.lines.Line2D at 0x19c6a210>,
#  <matplotlib.lines.Line2D at 0x19c6a890>,
#  <matplotlib.lines.Line2D at 0x19c6ab90>,
#  <matplotlib.lines.Line2D at 0x19c6af90>,
#  <matplotlib.lines.Line2D at 0x19c6ac90>,
#  <matplotlib.lines.Line2D at 0x19c6af50>,
#  <matplotlib.lines.Line2D at 0x19c7f250>,
#  <matplotlib.lines.Line2D at 0x19c7f410>,
#  <matplotlib.lines.Line2D at 0x19c7f5d0>,
#  <matplotlib.lines.Line2D at 0x19c7f790>,
#  <matplotlib.lines.Line2D at 0x19c7f950>,
#  <matplotlib.lines.Line2D at 0x19c7fb10>,
#  <matplotlib.lines.Line2D at 0x19c7fcd0>,
#  <matplotlib.lines.Line2D at 0x19c7fe90>,
#  <matplotlib.lines.Line2D at 0x19c84090>,
#  <matplotlib.lines.Line2D at 0x19c84250>,
#  <matplotlib.lines.Line2D at 0x19c84410>,
#  <matplotlib.lines.Line2D at 0x19c845d0>,
#  <matplotlib.lines.Line2D at 0x19c84790>,
#  <matplotlib.lines.Line2D at 0x19c7fd10>,
#  <matplotlib.lines.Line2D at 0x19c84b10>,
#  <matplotlib.lines.Line2D at 0x19c84cd0>,
#  <matplotlib.lines.Line2D at 0x19c84e90>,
#  <matplotlib.lines.Line2D at 0x19c7b950>,
#  <matplotlib.lines.Line2D at 0x19c7be10>,
#  <matplotlib.lines.Line2D at 0x19c7bf50>,
#  <matplotlib.lines.Line2D at 0x19c84990>,
#  <matplotlib.lines.Line2D at 0x19c7bc90>,
#  <matplotlib.lines.Line2D at 0x19c7b450>,
#  <matplotlib.lines.Line2D at 0x19c7b490>,
#  <matplotlib.lines.Line2D at 0x19c7b110>,
#  <matplotlib.lines.Line2D at 0x19c7b6d0>,
#  <matplotlib.lines.Line2D at 0x19c88150>,
#  <matplotlib.lines.Line2D at 0x19c7bc10>,
#  <matplotlib.lines.Line2D at 0x19c88610>,
#  <matplotlib.lines.Line2D at 0x19c881d0>,
#  <matplotlib.lines.Line2D at 0x19c88290>,
#  <matplotlib.lines.Line2D at 0x19c88e10>,
#  <matplotlib.lines.Line2D at 0x19c88f90>,
#  <matplotlib.lines.Line2D at 0x19c88a50>,
#  <matplotlib.lines.Line2D at 0x19c88ad0>,
#  <matplotlib.lines.Line2D at 0x19c4b090>,
#  <matplotlib.lines.Line2D at 0x19c4b250>,
#  <matplotlib.lines.Line2D at 0x19c4b410>,
#  <matplotlib.lines.Line2D at 0x19c4b5d0>,
#  <matplotlib.lines.Line2D at 0x19c4b790>,
#  <matplotlib.lines.Line2D at 0x19c4b950>,
#  <matplotlib.lines.Line2D at 0x19c88a90>,
#  <matplotlib.lines.Line2D at 0x19c4bcd0>,
#  <matplotlib.lines.Line2D at 0x19c4be90>,
#  <matplotlib.lines.Line2D at 0x19c60090>,
#  <matplotlib.lines.Line2D at 0x19c60250>,
#  <matplotlib.lines.Line2D at 0x19c60410>,
#  <matplotlib.lines.Line2D at 0x19c605d0>,
#  <matplotlib.lines.Line2D at 0x19c4bb50>,
#  <matplotlib.lines.Line2D at 0x19c60950>,
#  <matplotlib.lines.Line2D at 0x19c60b10>,
#  <matplotlib.lines.Line2D at 0x19c60cd0>,
#  <matplotlib.lines.Line2D at 0x19c60e90>,
#  <matplotlib.lines.Line2D at 0x19c5c090>,
#  <matplotlib.lines.Line2D at 0x19c5c250>,
#  <matplotlib.lines.Line2D at 0x19c607d0>,
#  <matplotlib.lines.Line2D at 0x19c5c5d0>,
#  <matplotlib.lines.Line2D at 0x19c5c790>,
#  <matplotlib.lines.Line2D at 0x19c5c950>,
#  <matplotlib.lines.Line2D at 0x19c5cb10>,
#  <matplotlib.lines.Line2D at 0x19c5ccd0>,
#  <matplotlib.lines.Line2D at 0x19c5ce90>,
#  <matplotlib.lines.Line2D at 0x19c5c450>,
#  <matplotlib.lines.Line2D at 0x19c75250>,
#  <matplotlib.lines.Line2D at 0x19c75410>,
#  <matplotlib.lines.Line2D at 0x19c755d0>,
#  <matplotlib.lines.Line2D at 0x19c75790>,
#  <matplotlib.lines.Line2D at 0x19c75950>,
#  <matplotlib.lines.Line2D at 0x19c75b10>,
#  <matplotlib.lines.Line2D at 0x19c75cd0>,
#  <matplotlib.lines.Line2D at 0x19c75e90>,
#  <matplotlib.lines.Line2D at 0x19c86090>,
#  <matplotlib.lines.Line2D at 0x19c86250>,
#  <matplotlib.lines.Line2D at 0x19c86410>,
#  <matplotlib.lines.Line2D at 0x19c865d0>,
#  <matplotlib.lines.Line2D at 0x19c86790>,
#  <matplotlib.lines.Line2D at 0x19c75d10>,
#  <matplotlib.lines.Line2D at 0x19c86b10>,
#  <matplotlib.lines.Line2D at 0x19c86cd0>,
#  <matplotlib.lines.Line2D at 0x19c86e90>,
#  <matplotlib.lines.Line2D at 0x19c76090>,
#  <matplotlib.lines.Line2D at 0x19c76250>,
#  <matplotlib.lines.Line2D at 0x19c76410>,
#  <matplotlib.lines.Line2D at 0x19c86990>,
#  <matplotlib.lines.Line2D at 0x19c76790>,
#  <matplotlib.lines.Line2D at 0x19c76950>,
#  <matplotlib.lines.Line2D at 0x19c76b10>,
#  <matplotlib.lines.Line2D at 0x19c76cd0>,
#  <matplotlib.lines.Line2D at 0x19c76e90>,
#  <matplotlib.lines.Line2D at 0x19c80810>,
#  <matplotlib.lines.Line2D at 0x19c76610>,
#  <matplotlib.lines.Line2D at 0x19c80fd0>,
#  <matplotlib.lines.Line2D at 0x19c80e10>,
#  <matplotlib.lines.Line2D at 0x19c80e50>,
#  <matplotlib.lines.Line2D at 0x19c80510>,
#  <matplotlib.lines.Line2D at 0x19c80590>,
#  <matplotlib.lines.Line2D at 0x19c80190>,
#  <matplotlib.lines.Line2D at 0x19c80210>,
#  <matplotlib.lines.Line2D at 0x2332b050>,
#  <matplotlib.lines.Line2D at 0x2332b850>,
#  <matplotlib.lines.Line2D at 0x2332b110>,
#  <matplotlib.lines.Line2D at 0x2332bd90>,
#  <matplotlib.lines.Line2D at 0x2332b410>,
#  <matplotlib.lines.Line2D at 0x2332b450>,
#  <matplotlib.lines.Line2D at 0x19c80290>,
#  <matplotlib.lines.Line2D at 0x2332b510>,
#  <matplotlib.lines.Line2D at 0x2332bc90>,
#  <matplotlib.lines.Line2D at 0x2331e090>,
#  <matplotlib.lines.Line2D at 0x2331e250>,
#  <matplotlib.lines.Line2D at 0x2331e410>,
#  <matplotlib.lines.Line2D at 0x2331e5d0>,
#  <matplotlib.lines.Line2D at 0x2332b750>,
#  <matplotlib.lines.Line2D at 0x2331e950>,
#  <matplotlib.lines.Line2D at 0x2331eb10>,
#  <matplotlib.lines.Line2D at 0x2331ecd0>,
#  <matplotlib.lines.Line2D at 0x2331ee90>,
#  <matplotlib.lines.Line2D at 0x23327090>,
#  <matplotlib.lines.Line2D at 0x23327250>,
#  <matplotlib.lines.Line2D at 0x2331e7d0>,
#  <matplotlib.lines.Line2D at 0x233275d0>,
#  <matplotlib.lines.Line2D at 0x23327790>,
#  <matplotlib.lines.Line2D at 0x23327950>,
#  <matplotlib.lines.Line2D at 0x23327b10>,
#  <matplotlib.lines.Line2D at 0x23327cd0>,
#  <matplotlib.lines.Line2D at 0x23327e90>,
#  <matplotlib.lines.Line2D at 0x23327450>,
#  <matplotlib.lines.Line2D at 0x2332c250>,
#  <matplotlib.lines.Line2D at 0x2332c410>,
#  <matplotlib.lines.Line2D at 0x2332c5d0>,
#  <matplotlib.lines.Line2D at 0x2332c790>,
#  <matplotlib.lines.Line2D at 0x2332c950>,
#  <matplotlib.lines.Line2D at 0x2332cb10>,
#  <matplotlib.lines.Line2D at 0x2332ccd0>,
#  <matplotlib.lines.Line2D at 0x2332ce90>,
#  <matplotlib.lines.Line2D at 0x23357c50>,
#  <matplotlib.lines.Line2D at 0x23357490>,
#  <matplotlib.lines.Line2D at 0x23357090>,
#  <matplotlib.lines.Line2D at 0x23357190>,
#  <matplotlib.lines.Line2D at 0x23357650>,
#  <matplotlib.lines.Line2D at 0x2332cd10>,
#  <matplotlib.lines.Line2D at 0x23357e10>,
#  <matplotlib.lines.Line2D at 0x23357910>,
#  <matplotlib.lines.Line2D at 0x23357710>,
#  <matplotlib.lines.Line2D at 0x23350ad0>,
#  <matplotlib.lines.Line2D at 0x23350310>,
#  <matplotlib.lines.Line2D at 0x23350510>,
#  <matplotlib.lines.Line2D at 0x23357d10>,
#  <matplotlib.lines.Line2D at 0x23350890>,
#  <matplotlib.lines.Line2D at 0x23350a50>,
#  <matplotlib.lines.Line2D at 0x23350dd0>,
#  <matplotlib.lines.Line2D at 0x23350990>,
#  <matplotlib.lines.Line2D at 0x23350050>,
#  <matplotlib.lines.Line2D at 0x23346650>,
#  <matplotlib.lines.Line2D at 0x23350790>,
#  <matplotlib.lines.Line2D at 0x23346c10>,
#  <matplotlib.lines.Line2D at 0x23346ed0>,
#  <matplotlib.lines.Line2D at 0x233464d0>,
#  <matplotlib.lines.Line2D at 0x233466d0>,
#  <matplotlib.lines.Line2D at 0x233462d0>,
#  <matplotlib.lines.Line2D at 0x23346890>,
#  <matplotlib.lines.Line2D at 0x23346ad0>,
#  <matplotlib.lines.Line2D at 0x2333cb90>,
#  <matplotlib.lines.Line2D at 0x2333c750>,
#  <matplotlib.lines.Line2D at 0x2333cb10>,
#  <matplotlib.lines.Line2D at 0x2333c290>,
#  <matplotlib.lines.Line2D at 0x2333c590>,
#  <matplotlib.lines.Line2D at 0x2333c990>,
#  <matplotlib.lines.Line2D at 0x23346cd0>,
#  <matplotlib.lines.Line2D at 0x2333ccd0>,
#  <matplotlib.lines.Line2D at 0x2333cbd0>,
#  <matplotlib.lines.Line2D at 0x23334950>,
#  <matplotlib.lines.Line2D at 0x23334310>,
#  <matplotlib.lines.Line2D at 0x23334790>,
#  <matplotlib.lines.Line2D at 0x23334b50>,
#  <matplotlib.lines.Line2D at 0x2333c050>,
#  <matplotlib.lines.Line2D at 0x23334d90>,
#  <matplotlib.lines.Line2D at 0x23334690>,
#  <matplotlib.lines.Line2D at 0x23334050>,
#  <matplotlib.lines.Line2D at 0x23334a50>,
#  <matplotlib.lines.Line2D at 0x2333e4d0>,
#  <matplotlib.lines.Line2D at 0x2333e750>,
#  <matplotlib.lines.Line2D at 0x23334dd0>,
#  <matplotlib.lines.Line2D at 0x2333ed10>,
#  <matplotlib.lines.Line2D at 0x2333ee50>]
