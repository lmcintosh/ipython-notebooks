# %%
import numpy as np
from scipy.interpolate import interp1d
from scipy.signal import fftconvolve
#from numpy import fft
from scipy import fft, arange
from scipy.stats import sem
from random import randint
from cmath import polar
from numpy.fft import fft2
from numpy.fft import fftshift

from lnl_model_functions import *

# %%
import brewer2mpl
import time

# %%
from info_theory_functions import *

# %% [markdown]
# # Select image directory

# %%
#im_path = '/Users/lmcintosh/Documents/Natural_Images/RawData/cd13A' # flood plain, water, horizon
#im_path = '/Volumes/Lane/RawData/cd13A' # flood plain, water, horizon
#im_path = '/Volumes/Lane/RawData/cd01A' # baboons, trees, bushes
im_path = '/Users/lmcintosh/Documents/Natural_Images/imc'
#im_path = '/home/lane/Natural_images/imc'

# %%
ls -1 $im_path | wc -l
# Out:
#      400

# %% [markdown]
# # Functions for loading images

# %%
def load_images(path, numImages, patchSize=None, acceptedExtensions=['.imc','LUM.mat'], square=False):
    from os import listdir
    from os.path import isfile, join
    import array as ar
    import scipy.io
    
    allfiles = []
    for ext in acceptedExtensions:
        allfiles = allfiles + [f for f in listdir(path) if isfile(join(path,f)) and ext in f]
    if len(allfiles) < numImages:
        print 'Only ' + str(len(allfiles)) + ' files in directory.'
    names    = allfiles[:numImages]
    patches  = []

    for im in names:
        if '.imc' in im:
            fin = open(path+'/'+im, 'rb')
            s   = fin.read()
            fin.close()
            arr = ar.array('H', s)
            arr.byteswap()
            img = np.array(arr, dtype='uint16').reshape(1024,1536)
        elif '.mat' in im:
            fin = scipy.io.loadmat(path+'/'+im)
            arr = fin['LUM_Image']
            # make 0 to 255
            arr = arr - min(arr.flat)
            arr = 255.*arr/max(arr.flat)
            img = np.array(arr, dtype='uint16')
            
        # make patches
        if patchSize:
            img_center = [np.shape(img)[0]/2,np.shape(img)[1]/2]
            img        = img[img_center[0]-patchSize/2:img_center[0]+patchSize/2,img_center[1]-patchSize/2:img_center[1]+patchSize/2]
            
        if square:
            N = min(shape(img))
            N = N - (N % 2) # make even
            img = img[:N,:N]
        
        # normalize to unit variance and zero mean
        #img        = img/np.sqrt(np.var(img))
        patches.append(img)

    return patches

# %% [markdown]
# # Load image dataset

# %%
numImages = 400
patchSize = None
pixelsToDeg = 92./2
averageGanglionSize = 1.5*pixelsToDeg+1 # in pixels

# %%
patches = load_images(im_path, numImages, patchSize, square=True)

# %%
# # fix center to 0.25, vary surround [0.5, 1, 2]
# sfilter1 = [spatial_filter_2d(c_width=0.25, s_width=s, xs_num=averageGanglionSize) for s in [0.375, 0.5, 1., 2.]]
# sfilter2 = [spatial_filter_2d(c_width=0.25, s_width=s, xs_num=averageGanglionSize) for s in [0.375, 0.5, 1., 2.]]

# %% [markdown]
# # Define noise model

# %%
def noise_var(m, w):
    '''INPUT: m is mean, w is standard deviation
       OUTPUT: variance of noise'''
    contrast = w/abs(m)
    snr = 15.1*contrast + 2.06
    return (w**2)/snr

# %% [markdown]
# # Define coefficients

# %%
def gaussian2d(xs, sigma):
    '''Returns 2d symmetric Gaussian'''
    p = gaussian(x=xs, sigma=sigma)
    p_2d = zeros((len(p),len(p)))
    for idx,x in enumerate(xs):
        for idy,y in enumerate(xs):
            p_2d[idx,idy] = p[np.min([int(np.sqrt((idx-np.floor(len(xs)/2.))**2 
                                                     + (idy-np.floor(len(xs)/2.))**2) + np.floor(len(xs)/2.)), len(xs)-1])]
    return p_2d

# %%
def coeff(centerStrength, centerSize, horzStrength, horzSize, amaStrength, amaSize, receptiveFieldSize=averageGanglionSize):
    '''Compute 2d linear coefficients for receptive field. Arguments are strength
    and size of excitatory center, horizontal surround, and amacrine surround.
    ASSUMPTIONS: each contribution is a spherically symmetrical gaussian.'''
    x = np.linspace(-10,10,receptiveFieldSize)
    return centerStrength*gaussian2d(xs=x, sigma=centerSize) \
                - horzStrength*gaussian2d(xs=x, sigma=horzSize) \
                - amaStrength*gaussian2d(xs=x, sigma=amaSize)

# %%
exampleRF = coeff(centerStrength=1., centerSize=0.25, horzStrength=0.8, horzSize=1., amaStrength=0.2, amaSize=0.5)
plot(exampleRF[averageGanglionSize//2,:])

# %% [markdown]
# # Define objective function

# %%
def objective(args, images, outputShape=(10,10), nBins=10, eps=10e-5):
    filt = coeff(args[0],args[1],args[2],args[3],args[4],args[5])
    # filter then subsample images
    output = [subsample(fftconvolve(im, filt, mode='same'), outputShape) for im in images]
    outputWithNoise = [out + np.sqrt(noise_var(mean(out),np.std(out)))*randn(outputShape[0],outputShape[1]) for out in output]
    
    # pad binning in off-chance that output has zero entropy
    binning = np.linspace(np.min(outputWithNoise)-eps,np.max(outputWithNoise)+eps,nBins+1)

    H_r = entropy([item for sublist in outputWithNoise for subsublist in sublist for item in subsublist],Bins=[binning])
    H_r_s = []
    for out in outputWithNoise:
        H_r_s.append(entropy(out.flat,Bins=[binning]))
    return H_r - np.mean(H_r_s)

# %%
args = [1.,0.25,0.8,1.,0.2,0.5]
outputShape = (20,20)
filt = coeff(args[0],args[1],args[2],args[3],args[4],args[5])
# filter then subsample images
output = [subsample(fftconvolve(im, filt, mode='same'), outputShape) for im in patches]
outputWithNoise = [out + np.sqrt(noise_var(mean(out),np.std(out)))*randn(outputShape[0],outputShape[1]) for out in output]

# pad binning in off-chance that output has zero entropy
binning = np.linspace(np.min(outputWithNoise)-eps,np.max(outputWithNoise)+eps,nBins+1)

z = [item for sublist in outputWithNoise for subsublist in sublist for item in subsublist]
H_r = entropy([item for sublist in outputWithNoise for subsublist in sublist for item in subsublist],Bins=[binning])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-90-aa24f5e97d37> in <module>()
#       3 filt = coeff(args[0],args[1],args[2],args[3],args[4],args[5])
#       4 # filter then subsample images
# ----> 5 output = [subsample(fftconvolve(im, filt, mode='same'), outputShape) for im in patches]
#       6 outputWithNoise = [out + np.sqrt(noise_var(mean(out),np.std(out)))*randn(outputShape[0],outputShape[1]) for out in output]
#       7
#
# KeyboardInterrupt:

# %%
start = time.time()
info = objective([1.,0.25,0.8,1.,0.2,0.5],patches)
print time.time() - start
# Out:
# 41.6908159256

# %%
info
# Out:
# 0.14018380428113864

# %%
start = time.time()
info = objective([1.,0.25,0.8,1.,0.2,0.5],patches,outputShape=(40,40))
print time.time() - start
# Out:
# 43.042648077

# %%
info
# Out:
# 0.14141387619600565

# %%
start = time.time()
info = objective([1.,0.25,0.8,1.,0.2,0.5],patches,outputShape=(10,10))
print time.time() - start
# Out:
# 42.0930280685

# %%
info
# Out:
# 0.16166016652351245

# %%
start = time.time()
info = objective([1.,0.25,0.8,2.,0.2,.3],patches,outputShape=(10,10))
print time.time() - start
# Out:
# 41.3785459995

# %%
info
# Out:
# 0.16401992414431543

# %% [markdown]
# # Info computation takes way too long and too much memory, even using nearest neighbors

# %%
infoBetweenTwoImages = nnInfo(patches[0].flatten(),patches[1].flatten())

# %%
imshow(patches[0],cmap='gray')

# %%
out = subsample(patches[0], (20,20))
imshow(out + np.sqrt(noise_var(mean(out),np.std(out))), cmap='gray')

# %% [markdown]
# # Optimize

# %%
from scipy import optimize

# %%
# intial parameters
numParams = 6
params    = randn(numParams)
res       = optimize.minimize(objective, 
                              x0=params, 
                              args=tuple([patches]), 
                              method='nelder-mead', 
                              options={'xtol': 1e-8, 'disp': True})  #'maxiter' : 500
