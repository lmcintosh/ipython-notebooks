# %%
import numpy as np
from scipy.linalg import toeplitz
from scipy.linalg import inv
import brewer2mpl

# %%
def pinkNoise(duration):
    x_t    = np.random.randn(2*duration)
    x_f    = np.fft.rfft(x_t)[:len(x_t)/2]
    f      = linspace(1,duration,len(x_f))
    fi     = 1./f
    pink_f = x_f*fi

    return real(np.fft.ifft(pink_f))

# %%
x = pinkNoise(1000)
plot(x)

# %%
# generate upper triangular toeplitz matrix from x
tmp = zeros(len(x))
tmp[0] = x[0]
toeplitz(tmp,x)
# Out:
# array([[ 0.00144221, -0.0026365 , -0.00303122, ..., -0.00345368,
#          0.00244494,  0.00078048],
#        [ 0.        ,  0.00144221, -0.0026365 , ..., -0.00990344,
#         -0.00345368,  0.00244494],
#        [ 0.        ,  0.        ,  0.00144221, ..., -0.00956305,
#         -0.00990344, -0.00345368],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  0.00144221,
#         -0.0026365 , -0.00303122],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.00144221, -0.0026365 ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.00144221]])

# %%
bmap = brewer2mpl.get_map('Greys', 'sequential', 7)
imshow(np.outer(x,x), cmap=bmap.mpl_colormap)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x985ab00>

# %%
mean(x)
# Out:
# 0.029047038781531226

# %%
def getW(x,y):
    
    return np.inner(x,y)*inv(np.inner(x,x))
