# %%
import numpy as np
import pandas as pd
from scipy import fft
import datetime
from scipy.optimize import minimize
import urllib

# %%
cd ..
# Out:
# /home/lane

# %%
cd diamondhead/
# Out:
# /home/lane/diamondhead

# %%
#cd ~/Documents/DiamondHead/
cd /home/lane/diamondhead
# Out:
#   File "<ipython-input-12-3db2473c27cb>", line 2
#     cd ..
#         ^
# SyntaxError: invalid syntax

# %%
data = pd.read_csv('sp500_history.csv')

# %%
shareprices_open  = np.array(data['Open'])[::-1]
shareprices_close = np.array(data['Close'])[::-1]

# %%
(len(shareprices_open), len(shareprices_close))
# Out:
# (16272, 16272)

# %%
# Get relative prices (price_close/price_open)
X = [shareprices_close[t]/shareprices_open[t] for t in xrange(len(shareprices_open))]

# %%
fig = gcf()
fig.set_size_inches((18,4))
count,bins,patches = hist(X,100)

# %%
(np.mean(X),np.var(X))
# Out:
# (1.0002485751754049, 8.0097754518636049e-05)

# %%
# Expected return after entire period
from operator import mul
returns = reduce(mul, X, 1)

# %%
returns**(1/64.)
# Out:
# 1.0543803647771941

# %% [markdown]
# ## Import many different stocks

# %%
tickers = open("tickers_curated.txt", "r")
symbols = tickers.read().split('\r')

# %%
d = datetime.date.today()
yr_num   = d.year
mon_num  = d.month
day_num  = d.day
day_name = d.weekday()

# %%
data = []
for sym in symbols:
    url  = 'http://real-chart.finance.yahoo.com/table.csv?s=%s&d=%d&e=%d&f=%d&g=d&a=0&b=3&c=1950&ignore=.csv' % (sym,mon_num,day_num,yr_num)
    name = 'historical_data/historical_price_%s.csv' % (sym)
    urllib.urlretrieve(url,name)
    data.append(pd.read_csv(name))
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-19-91d087bdefc0> in <module>()
#       4     name = 'historical_data/historical_price_%s.csv' % (sym)
#       5     urllib.urlretrieve(url,name)
# ----> 6     data.append(pd.read_csv(name))
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols)
#     398             )
#     399
# --> 400         return _read(filepath_or_buffer, kwds)
#     401
#     402     parser_f.__name__ = name
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     203         return parser
#     204
# --> 205     return parser.read()
#     206
#     207 _parser_defaults = {
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in read(self, nrows)
#     606             #     self._engine.set_error_bad_lines(False)
#     607
# --> 608         ret = self._engine.read(nrows)
#     609
#     610         if self.options.get('as_recarray'):
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in read(self, nrows)
#    1026
#    1027         try:
# -> 1028             data = self._reader.read(nrows)
#    1029         except StopIteration:
#    1030             if nrows is None:
#
# /usr/local/lib/python2.7/dist-packages/pandas/parser.so in pandas.parser.TextReader.read (pandas/parser.c:6745)()
#
# /usr/local/lib/python2.7/dist-packages/pandas/parser.so in pandas.parser.TextReader._read_low_memory (pandas/parser.c:6964)()
#
# /usr/local/lib/python2.7/dist-packages/pandas/parser.so in pandas.parser.TextReader._read_rows (pandas/parser.c:7568)()
#
# /usr/local/lib/python2.7/dist-packages/pandas/parser.so in pandas.parser.TextReader._tokenize_rows (pandas/parser.c:7451)()
#
# /usr/local/lib/python2.7/dist-packages/pandas/parser.so in pandas.parser.raise_parser_error (pandas/parser.c:18744)()
#
# CParserError: Error tokenizing data. C error: Expected 1 fields in line 5, saw 4

# %%
type(data[0])

# %%
len(data)
# Out:
# 278

# %%
name
# Out:
# 'historical_data/historical_price_LSI.csv'

# %%
tmp = pd.read_csv(name)
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-21-b58964138ccf> in <module>()
# ----> 1 tmp = pd.read_csv(name)
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols)
#     398             )
#     399
# --> 400         return _read(filepath_or_buffer, kwds)
#     401
#     402     parser_f.__name__ = name
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     203         return parser
#     204
# --> 205     return parser.read()
#     206
#     207 _parser_defaults = {
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in read(self, nrows)
#     606             #     self._engine.set_error_bad_lines(False)
#     607
# --> 608         ret = self._engine.read(nrows)
#     609
#     610         if self.options.get('as_recarray'):
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in read(self, nrows)
#    1026
#    1027         try:
# -> 1028             data = self._reader.read(nrows)
#    1029         except StopIteration:
#    1030             if nrows is None:
#
# /usr/local/lib/python2.7/dist-packages/pandas/parser.so in pandas.parser.TextReader.read (pandas/parser.c:6745)()
#
# /usr/local/lib/python2.7/dist-packages/pandas/parser.so in pandas.parser.TextReader._read_low_memory (pandas/parser.c:6964)()
#
# /usr/local/lib/python2.7/dist-packages/pandas/parser.so in pandas.parser.TextReader._read_rows (pandas/parser.c:7568)()
#
# /usr/local/lib/python2.7/dist-packages/pandas/parser.so in pandas.parser.TextReader._tokenize_rows (pandas/parser.c:7451)()
#
# /usr/local/lib/python2.7/dist-packages/pandas/parser.so in pandas.parser.raise_parser_error (pandas/parser.c:18744)()
#
# CParserError: Error tokenizing data. C error: Expected 1 fields in line 5, saw 4

# %%
# portfolio weights
b = (1./len(data))*ones((len(data),))
sum(b)
# Out:
# 0.99999999999999389

# %%
# for a single time point (most recent)
Xs = [data[i]['Close'][0]/data[i]['Open'][0] for i in xrange(len(data))]

# %%
np.inner(b,Xs)
# Out:
# 0.99666625751606897

# %%
# for as far back as possible: 111 days
for t in xrange(0,365*(2014-1971)):
    Xs = [data[i]['Close'][t]/data[i]['Open'][t] for i in xrange(len(data))]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-af39cdc44120> in <module>()
#       1 # for as far back as possible
#       2 for t in xrange(0,365*(2014-1971)):
# ----> 3     Xs = [data[i]['Close'][t]/data[i]['Open'][t] for i in xrange(len(data))]
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     374     def __getitem__(self, key):
#     375         try:
# --> 376             return self.index.get_value(self, key)
#     377         except InvalidIndexError:
#     378             pass
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/pandas/core/index.py in get_value(self, series, key)
#     529         """
#     530         try:
# --> 531             return self._engine.get_value(series, key)
#     532         except KeyError, e1:
#     533             if len(self) > 0 and self.inferred_type == 'integer':
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/pandas/_engines.so in pandas._engines.IndexEngine.get_value (pandas/src/engines.c:1479)()
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/pandas/_engines.so in pandas._engines.IndexEngine.get_value (pandas/src/engines.c:1374)()
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/pandas/_engines.so in pandas._engines.DictIndexEngine.get_loc (pandas/src/engines.c:2498)()
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/pandas/_engines.so in pandas._engines.DictIndexEngine.get_loc (pandas/src/engines.c:2460)()
#
# KeyError: 111

# %%
def doubling_rate(b):
    rate = []
    for t in xrange(0,111):
        Xs = [data[i]['Close'][t]/data[i]['Open'][t] for i in xrange(len(data))]
        rate.append(np.log2(np.inner(b,Xs)))
        
    return np.mean(rate)

# %%
d = doubling_rate(b)
print d
# Out:
# 0.000181056359216

# %%
2**d
# Out:
# 1.000125506580205

# %%
def neg_doubling_rate(b):
    return -doubling_rate(b)

# %% [markdown]
# #### $b$'s must sum to 1

# %%
def constraint(x0):
    return 1. - np.sum(x0)

# %% [markdown]
# #### each $b > 0$

# %%
def positive_constraint(x0):
    return np.min(x0)

# %% [markdown]
# #### Note: constraints are ignored unless you explicitly force method to be SLSQP

# %%
res = minimize(neg_doubling_rate, x0=b, method='SLSQP', constraints=[{'type':'eq', 'fun':constraint},
                                                                     {'type':'ineq', 'fun':positive_constraint}])

# %%
fig = gcf()
fig.set_size_inches((16,4))
plot(res.x,'k')

# %%
sum(res.x)
# Out:
# 1.0000000000000004

# %%
constraint(res.x)
# Out:
# -4.4408920985006262e-16

# %% [markdown]
# ## Universal portfolio

# %%
# for as far back as possible: 111 days
Xs = zeros((len(data),111))
for t in xrange(0,111):
    Xs[:,t] = np.array([data[i]['Close'][t]/data[i]['Open'][t] for i in xrange(len(data))])

# %% [markdown]
# ### Buy and hold

# %%
b = (1./len(data))*ones((len(data),))
sum(b)
# Out:
# 0.99999999999999567

# %%
# end_return = 0.
# for s in xrange(len(data)):
#     end_return = end_return + b[s]*prod(Xs[0,:])
    
buy_and_hold = []
b = ones((len(data),))
end_return = 1.
for t in xrange(111):
    end_return = (1./len(data))*np.inner(b,Xs[:,t])
    buy_and_hold.append(end_return)
    b = np.array([prod(Xs[s,:t]) for s in xrange(len(data))])

# %%
end_return
# Out:
# 1.0218450267973103

# %%
plot(buy_and_hold)

# %% [markdown]
# ### Constantly rebalanced

# %%
constant_rebalancing = []
b = (1./len(data))*ones((len(data),))
end_return = 1.
for t in xrange(111):
    end_return = end_return*np.inner(b,Xs[:,t])
    constant_rebalancing.append(end_return)

#end_return = 1.
#tracker = []
#b = (1./len(data))*ones((len(data),))
#for t in xrange(111):
#    end_return = end_return*np.inner(b,Xs[:,t])
#    b = (1./len(data))*(1./Xs[:,t])
#    tracker.append(end_return)

# %%
end_return
# Out:
# 1.0149616917832716

# %%
plot(constant_rebalancing)

# %% [markdown]
# ### Comparison

# %%
fig = gcf()
fig.set_size_inches((14,4))

plot(buy_and_hold,'k',linewidth=2)
plot(constant_rebalancing,'r',linewidth=2)

# %% [markdown]
# ### Okay, so constantly-rebalanced portfolio basically smooths the volatility, but in an upward-moving market, the difference in returns is not significant (in fact, in this simulation, is actually worse)
