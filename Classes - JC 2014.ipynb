# %%
import brewer2mpl
from scipy.stats import pearsonr
from scipy.stats import spearmanr

# %%
cd ..
# Out:
# /home/lane

# %%
cd information-theory-toolbox/
# Out:
# /home/lane/information-theory-toolbox

# %%
from info_theory_functions import *

# %%
x = randn(10e2)
y = randn(10e2)

# %%
# Change the default colors
#mpl.rcParams['axes.color_cycle'] = 
colors = brewer2mpl.get_map('Set2', 'qualitative', 7).mpl_colors

#matplotlib.image.cmap = brewer2mpl.get_map('Set2', 'qualitative', 7).mpl_colormap

# I happen to know that there are 7 default colors in matplotlib
for i, color in enumerate(colors):
    plt.scatter(randn(10e2), randn(10e2), 
    color=color,
        edgecolors='grey',linewidths=0.1)

# %%
pearsonr(x,y)
# Out:
# (-0.0024468941547806885, 0.43906837887111183)

# %%
spearmanr(x,y)
# Out:
# (-0.0023341710041214171, 0.46044064358894388)

# %%
fig = gcf()
fig.set_size_inches((5,5))

colors = brewer2mpl.get_map('Set2', 'qualitative', 7).mpl_colors
y = x + 0.3*randn(10e2)
scatter(x, y, color=colors[-1], edgecolors='grey',linewidths=0.1)
#plot(sort(x),sort(y),'k--')

# %%
(pearsonr(x,y)[0]**2, spearmanr(x,y)[0]**2)
# Out:
# (0.91067013393100449, 0.90338610087911075)

# %%
(mutualinfo(x,y), nnInfo(x,y))
# Out:
# (1.4663399419171332, 1.6515620699965989)

# %%
def nonlinearity(x,K=1.,g=1.,theta=0.,mode='sigmoid',normalized=False):
    if normalized:
        if mode == 'sigmoid':
            n = K/(1+np.exp(-g*(x - theta)))
        elif mode == 'tanh':
            if type(x)==list or type(x)==numpy.ndarray:
                n = [g*tanh(a-theta) + K - g for a in x]
            else:
                n = g*tanh(x-theta) + K - g
        return np.array(n)/np.sqrt(np.var(np.array(n)))
    else:
        if mode == 'sigmoid':
            return K/(1+np.exp(-g*(x - theta)))
        elif mode == 'tanh':
            if type(x)==list or type(x)==numpy.ndarray:
                return [g*tanh(a-theta) + K - g for a in x]
            else:
                return g*tanh(x-theta) + K - g

# %%
fig = gcf()
fig.set_size_inches((5,5))

colors = brewer2mpl.get_map('Set2', 'qualitative', 7).mpl_colors
y = nonlinearity(x + 0.1*randn(10e2), K=1., g=5., theta=0) + 0.05*randn(10e2)
scatter(x, y, color=colors[-1], edgecolors='grey',linewidths=0.1)
#plot(sort(x),sort(y),'k--')

# %%
(pearsonr(x,y)[0]**2, spearmanr(x,y)[0]**2)
# Out:
# (0.79714490403750704, 0.90370972972456298)

# %%
(mutualinfo(x,y), nnInfo(x,y))
# Out:
# (1.4294085814158075, 1.7500348317815995)

# %%
from math import sin

# %%
fig = gcf()
fig.set_size_inches((5,5))

colors = brewer2mpl.get_map('Set2', 'qualitative', 7).mpl_colors
y = [cos(1.3*xi + 0.2*randn(1)) + 0.01*randn(1) for xi in x]
scatter(x, y, color=colors[-1], edgecolors='grey',linewidths=0.1)
#plot(sort(x),sort(y),'k--')

# %%
y = squeeze(y)

# %%
(pearsonr(x,np.array(y))[0]**2, spearmanr(x,np.array(y))[0]**2)
# Out:
# (0.015354223244272667, 0.015065051321251478)

# %%
(mutualinfo(x,y), nnInfo(x,y))
# Out:
# (1.2219780080446778, 1.8362829290154998)

# %%
fig = gcf()
fig.set_size_inches((5,5))

colors = brewer2mpl.get_map('Set2', 'qualitative', 7).mpl_colors
y = randn(10e2)
scatter(x, y, color=colors[-1], edgecolors='grey',linewidths=0.1)
#plot(sort(x),sort(y),'k--')

# %%
(pearsonr(x,np.array(y))[0]**2, spearmanr(x,np.array(y))[0]**2)
# Out:
# (0.001060341069878148, 0.0010041376898843753)

# %%
(mutualinfo(x,y), nnInfo(x,y))
# Out:
# (0.057680333823990182, -0.05500245413255378)
